# %% [markdown]
# <html>
# <table width="100%" cellspacing="2" cellpadding="2" border="1">
# <tbody>
# <tr>
# <td valign="center" align="center" width="25%"><img src="media/decartes.jpg"
# alt="DeCART Icon" width="128" height="171"><br>
# </td>
# <td valign="center" align="center" width="75%">
# <h1 align="center"><font size="+1">DeCART Summer School<br>
# for<br>
# Biomedical Data Science</font></h1></td>
# <td valign="center" align="center" width="25%"><img
# src="media/U_Health_stacked_png_red.png" alt="Utah Health
# Logo" width="128" height="134"><br>
# </td>
# </tr>
# </tbody>
# </table>
# <br>
# </html>
#
# # Basic Numeric Data Characterization
#
# Numpy provides a number of functions/methods for characterizing

# %%
import os
import numpy as np
import utils
import numpy.random as ra
import pandas as pd

# %%
from quizzes.characterizing_numeric_data import *

# %%
pd.__version__
# Out:
# '0.23.1'

# %%
DATADIR = os.path.join(os.path.expanduser("~"),"DATA")
HRDIR = os.path.join(DATADIR,"Numerics", "mimic2", "hr", "subjects")
BPDIR = os.path.join(DATADIR,"Numerics", "mimic2", "bp", "subjects")

hr_files = os.listdir(HRDIR)

# %% [markdown]
# ## Heart Rate file for patient ``3325``
#
# We are going to start with using [Pandas](http://pandas.pydata.org/) to read, summarize, and visualize numeric data. We are going to start with the MIMIC2 patient ``#3325``. This is what the first five lines of the file looks like (You can explore this in the Linux shell with less, more, or cat.
#
# ```Python
# 88
# 84
# 87
# 78
# 85
# ```
#
# Pandas has two basic functions for reading in tabular data: [``read_table``](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html) and [``read_csv``](https://pandas.pydata.org/pandas-docs/stable/generat
#
# ed/pandas.read_csv.html). They are really the smae function with different default values for the delimiter, the character that is used to separate the data on each row: (a tab (``\t``) character for ``read_table`` and a comma (``,``) for ``read_csv``. We will use ``read_table`` to read in the heart rate values.
#
# Both of these functions swill return a [Pandas DataFrame](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html) which is a
# >Two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns).
#
# Going back to an earlier analogy, a data structure is a complex molecule of data.
#
# A Pandas DataFrame is an object (everything is an object), and so it has attributes and methods. Two of the methods we will use right off the bat are
#
# * [``head()``](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html#pandas.DataFrame.head)
# * [``tail()``](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.tail.html#pandas.DataFrame.tail)
#
# which return the first (last) n (default=5) rows of the DataFrame.
#
# ### Read in the data and look at the head

# %%
hr = pd.read_table(os.path.join(HRDIR,'3235.txt'))
hr.head()
# Out:
#    88
# 0  84
# 1  87
# 2  78
# 3  85
# 4  80

# %% [markdown]
# The DataFrame provides an **index** for each row (e.g. $0, 1, 2, \cdots$). It will also display the label (name) for each column.
#
# ### Does anything seem wrong?

# %%
hr.shape, hr.size
# Out:
# ((482, 1), 482)

# %% [markdown]
# ### Reread the data, specifying what to use for the header

# %%
hr = pd.read_table(os.path.join(HRDIR,'3235.txt'), header=None)
hr.head()
# Out:
#     0
# 0  88
# 1  84
# 2  87
# 3  78
# 4  85

# %% [markdown]
# This looks better but zero for a column label/name is not very meaningful. We can provide names to use for the columns with a ``names`` keyword argument.
#
# ### Reread the data providing a name for the heart rate column

# %%
hr = pd.read_table(os.path.join(HRDIR,'3235.txt'), header=None, names=["Heart Rate",])
hr.head()
# Out:
#    Heart Rate
# 0          88
# 1          84
# 2          87
# 3          78
# 4          85

# %% [markdown]
# ### DataFrame Attributes
#
# DataFrames have attributes that describe it, including
#
# * ``shape``: shape of the frame
# * ``size``: total number of elements in the frame
# * ``dtypes``: the data types for each column in the frame

# %%
print(hr.shape, hr.size)
print(hr.dtypes)
# Out:
# (483, 1) 483
# Heart Rate    int64
# dtype: object

# %% [markdown]
# ## Exercise
#
# Use the Pandas ``read_table``function to read in the blood pressure data for the same patient (``3235``). Answer the following questions:
#
# 1. How many rows are in the blood pressure data frame?
# 1. What data type (e.g. np.uint8) is used for the first column (systolic) of measurements?

# %%
bp = pd.read_table(os.path.join(BPDIR,'3235.txt'), header=None, names=["Sys BP", "Di BP"])
bp.head()
print(bp.size)
print(bp["Di BP"].dtypes)
data_shape(int(bp.size / 2))
# Out:
# 970
# int64
# 'You provided the correct number of rows'

# %% [markdown]
# #### Compute summary statistics
#
# We can compute summary statistics on a Pandas DataFrame or Series using either a numpy function or a method of the DataFrame or Series.
#
# ### How do we know what numpy functions are defined or what methods a DataFrame has?

# %%
print(hr.max())
# Out:
# Heart Rate    303
# dtype: int64

# %%
np.max(hr)
# Out:
# Heart Rate    303
# dtype: int64

# %%
np.max(hr["Heart Rate"])
# Out:
# 303

# %%
hr["Heart Rate"].max()
# Out:
# 303

# %% [markdown]
# ## Exercise
#
# What is the median value of the diastolic blood pressure for patient 3235?

# %%
print(bp["Di BP"].median())
median_diastolic(bp["Di BP"].median())
# Out:
# 54.0
# 'You provided the correct median value'

# %% [markdown]
# ### Python Aside
#
# It can often become confusing of what variables (including functions) are alive and well in your workspace. Python provides some functions for exploring this question:
#
# * `dir()`
# * `globals()`
# * `locals()`
#
# IPython provides magics for this `%who` and `%whos`
#
# I find keeping track of variables in Jupyter notebooks more important than in traditional scripting because I end up with a lot of global variables.

# %%
# %who
# Out:
# BPDIR	 DATADIR	 HRDIR	 assert_equal	 bp	 data_shape	 data_types	 hr	 hr_files
# median_diastolic	 np	 numbers	 os	 pd	 ra	 utils	 value

# %%
# %whos
# Out:
# Variable           Type         Data/Info
# -----------------------------------------
# BPDIR              str          /home/snowpile/DATA/Numerics/mimic2/bp/subjects
# DATADIR            str          /home/snowpile/DATA
# HRDIR              str          /home/snowpile/DATA/Numerics/mimic2/hr/subjects
# assert_equal       method       <bound method TestCase.as<...>al.Dummy testMethod=nop>>
# bp                 DataFrame         Sys BP  Di BP\n0    <...>n\n[485 rows x 2 columns]
# data_shape         function     <function data_shape at 0x7fb11766ec80>
# data_types         function     <function data_types at 0x7fb11766ed90>
# hr                 DataFrame         Heart Rate\n0       <...>n\n[483 rows x 1 columns]
# hr_files           list         n=3903
# median_diastolic   function     <function median_diastolic at 0x7fb116fc0bf8>
# np                 module       <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# numbers            module       <module 'numbers' from '/<...>ib/python3.5/numbers.py'>
# os                 module       <module 'os' from '/opt/c<...>nda/lib/python3.5/os.py'>
# pd                 module       <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# ra                 module       <module 'numpy.random' fr<...>umpy/random/__init__.py'>
# utils              module       <module 'utils' from '/ho<...>ot_camp_2_2018/utils.py'>
# value              float64      54.0

# %% [markdown]
# ## Exercise
#
# To explore equality of floating point numbers, perturb your answer by adding ``0.1``, ``0.01``, etc. until your perturbed answer is considered equal.

# %%
text = ''
constant = 0.1
while text != 'Done':
    constant = constant / 10
    if "not" in median_diastolic(bp["Di BP"].median() + constant)[0]:
        text = ''
    else:
        text = 'Done'
print(constant)
# Out:
# 1e-15

# %% [markdown]
# ## [``describe()``](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html)
#
# Pandas DataFrames (Series) come with a ``describe()`` method that provides summary statistics.

# %%
hr.describe()
# Out:
#        Heart Rate
# count  483.000000
# mean    92.857143
# std     14.398532
# min     75.000000
# 25%     85.000000
# 50%     90.000000
# 75%     99.000000
# max    303.000000

# %% [markdown]
# ## Creating a New Column
#
# We can create a new column in the DataFrame with a simple assignment statement:

# %%
hr["one"] = 1
hr["range"] = range(len(hr))
hr["inverse range"] = range(len(hr),0, -1)
hr.head()
# Out:
#    Heart Rate  one  range  inverse range
# 0          88    1      0            483
# 1          84    1      1            482
# 2          87    1      2            481
# 3          78    1      3            480
# 4          85    1      4            479

# %% [markdown]
# We can also create a new column based on a function of the existing columns.
#
# We can do this in two ways
#
# ### Method 1

# %%
hr["range_diff"] = hr["inverse range"] - hr["range"]
hr.head()
# Out:
#    Heart Rate  one  range  inverse range  range_diff
# 0          88    1      0            483         483
# 1          84    1      1            482         481
# 2          87    1      2            481         479
# 3          78    1      3            480         477
# 4          85    1      4            479         475

# %% [markdown]
# ### Method 2
#
# Our second method uses the [``apply()``]() method and a function. For this, I frequently use [**anonymous function**](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions).
#
# #### Anonymous Functions
#
# The syntax for anonymous functions is as follows:
#
# ```Python
# lambda variable(s): some_function_of_the_variable(s)
# ```
#
# So an anonymous doubling function would be
#
# ```Python
# lambda x: 2*x
# ```
#
# Here is an anonymous function that returns the upper case version of a string
#
# ```Python
# lambda y: y.upper()
# ```
#
# #### Pandas ``apply()``
#
# * ``apply()`` applies a function to each element in the DataFrame (Series)
# * We specify whether we want to apply the function by columns or rows by specifying the keyword argument ``axis`` (which defaults to 0 for columns)
#     * Remembering to set `axis` is very important and something I frequently to do
# * When we apply by rows, we get a variable that contains each row; we can access specific columns within the row

# %%
hr["range_diff2"] = hr.apply(lambda  row: row["range_diff"] - row["range"], axis=1)
hr.head()
# Out:
#    Heart Rate  one  range  inverse range  range_diff  range_diff2
# 0          88    1      0            483         483          483
# 1          84    1      1            482         481          480
# 2          87    1      2            481         479          477
# 3          78    1      3            480         477          474
# 4          85    1      4            479         475          471

# %% [markdown]
# ## Exercise:
#
# [Data standardization](http://scikit-learn.org/stable/modules/preprocessing.html) transforms numeric data ($x$) by subtracting the mean ($\mu_x$) and dividing by the standard deviation ($\sigma_x$):
#
# $$\tilde{x} = \frac{x-\mu_x}{\sigma_x}$$
#
# Read in one of the heart rate data files and compute the standardized form of the data. Assign this normalized heart rate to the DataFrame with a label of **"normalized hr"**.

# %%
hr["normalized hr"] = hr.apply(lambda  row: (row["Heart Rate"] - hr["Heart Rate"].mean()) / hr["Heart Rate"].std(), axis=1)
hr.head()
# Out:
#    Heart Rate  one  range  inverse range  range_diff  range_diff2  \
# 0          88    1      0            483         483          483
# 1          84    1      1            482         481          480
# 2          87    1      2            481         479          477
# 3          78    1      3            480         477          474
# 4          85    1      4            479         475          471
#
#    normalized hr
# 0      -0.337336
# 1      -0.615142
# 2      -0.406788
# 3      -1.031851
# 4      -0.545691

# %% [markdown]
# ## Exercise
#
#
# The student's t-test is often used to comapre two populations. Using ``len``, ``math.sqrt`` and numpy methods/functions compute the [t value](https://en.wikipedia.org/wiki/Student%27s_t-test#Independent_two-sample_t-test) for two files.
#
# $$t = \frac{\bar{{X_1}}-\bar{X_2}}{s_{X_1X_2}\sqrt{\frac{1}{n_1}+\frac{1}{n_2}}}$$ where
# $$s_{X_1X_2} = \sqrt{\frac{(n_1-1)s_{X_1}^2 + (n_2-1)s_{X_2}^2}{n_1+n_2-2}}$$.
# 1. Pick two heart rate files and comptue the t value for the two files.

# %%
# %%bash
# cd ~/DATA/Numerics/mimic2/hr/subjects
# ls -l
# # hr = pd.read_table(os.path.join(HRDIR,'3235.txt'), header=None, names=["Heart Rate",])
# Out:
# total 3670
# -rwxr-xr-x 1 root root    72 Feb  2 12:21 10006.txt
# -rwxr-xr-x 1 root root  3144 Feb  2 12:19 1000.txt
# -rwxr-xr-x 1 root root   938 Feb  2 12:19 10011.txt
# -rwxr-xr-x 1 root root   134 Feb  2 12:19 10019.txt
# -rwxr-xr-x 1 root root   218 Feb  2 12:21 10026.txt
# -rwxr-xr-x 1 root root   665 Feb  2 12:19 10027.txt
# -rwxr-xr-x 1 root root   256 Feb  2 12:20 10029.txt
# -rwxr-xr-x 1 root root   310 Feb  2 12:21 10032.txt
# -rwxr-xr-x 1 root root    73 Feb  2 12:19 10033.txt
# -rwxr-xr-x 1 root root   213 Feb  2 12:21 10040.txt
# -rwxr-xr-x 1 root root   750 Feb  2 12:20 10045.txt
# -rwxr-xr-x 1 root root   143 Feb  2 12:21 10046.txt
# -rwxr-xr-x 1 root root    34 Feb  2 12:21 10070.txt
# -rwxr-xr-x 1 root root   651 Feb  2 12:19 10076.txt
# -rwxr-xr-x 1 root root   224 Feb  2 12:19 10083.txt
# -rwxr-xr-x 1 root root   664 Feb  2 12:20 10088.txt
# -rwxr-xr-x 1 root root   163 Feb  2 12:20 10089.txt
# -rwxr-xr-x 1 root root   119 Feb  2 12:21 10093.txt
# -rwxr-xr-x 1 root root   612 Feb  2 12:21 10094.txt
# -rwxr-xr-x 1 root root   106 Feb  2 12:19 1010.txt
# -rwxr-xr-x 1 root root   254 Feb  2 12:21 10114.txt
# -rwxr-xr-x 1 root root   335 Feb  2 12:21 10117.txt
# -rwxr-xr-x 1 root root   779 Feb  2 12:20 10119.txt
# -rwxr-xr-x 1 root root   177 Feb  2 12:20 10130.txt
# -rwxr-xr-x 1 root root   321 Feb  2 12:21 10150.txt
# -rwxr-xr-x 1 root root   311 Feb  2 12:21 10154.txt
# -rwxr-xr-x 1 root root   131 Feb  2 12:21 10159.txt
# -rwxr-xr-x 1 root root   227 Feb  2 12:21 10163.txt
# -rwxr-xr-x 1 root root  4474 Feb  2 12:20 10168.txt
# -rwxr-xr-x 1 root root   182 Feb  2 12:19 10173.txt
# -rwxr-xr-x 1 root root  7223 Feb  2 12:20 10188.txt
# -rwxr-xr-x 1 root root   234 Feb  2 12:19 10193.txt
# -rwxr-xr-x 1 root root  1569 Feb  2 12:20 10217.txt
# -rwxr-xr-x 1 root root    98 Feb  2 12:19 10235.txt
# -rwxr-xr-x 1 root root   270 Feb  2 12:21 10237.txt
# -rwxr-xr-x 1 root root   521 Feb  2 12:20 10241.txt
# -rwxr-xr-x 1 root root    20 Feb  2 12:21 10245.txt
# -rwxr-xr-x 1 root root   369 Feb  2 12:19 10251.txt
# -rwxr-xr-x 1 root root   341 Feb  2 12:19 10272.txt
# -rwxr-xr-x 1 root root   952 Feb  2 12:21 10277.txt
# -rwxr-xr-x 1 root root  2722 Feb  2 12:19 10288.txt
# -rwxr-xr-x 1 root root  2355 Feb  2 12:21 10299.txt
# -rwxr-xr-x 1 root root   265 Feb  2 12:21 10301.txt
# -rwxr-xr-x 1 root root   404 Feb  2 12:20 10302.txt
# -rwxr-xr-x 1 root root   421 Feb  2 12:20 10305.txt
# -rwxr-xr-x 1 root root   223 Feb  2 12:21 10306.txt
# -rwxr-xr-x 1 root root   218 Feb  2 12:20 10311.txt
# -rwxr-xr-x 1 root root   176 Feb  2 12:20 10314.txt
# -rwxr-xr-x 1 root root  2414 Feb  2 12:20 10315.txt
# -rwxr-xr-x 1 root root   608 Feb  2 12:21 10327.txt
# -rwxr-xr-x 1 root root    52 Feb  2 12:20 10330.txt
# -rwxr-xr-x 1 root root   223 Feb  2 12:20 10339.txt
# -rwxr-xr-x 1 root root   118 Feb  2 12:19 10356.txt
# -rwxr-xr-x 1 root root    50 Feb  2 12:20 10362.txt
# -rwxr-xr-x 1 root root  3122 Feb  2 12:21 10375.txt
# -rwxr-xr-x 1 root root   233 Feb  2 12:21 10379.txt
# -rwxr-xr-x 1 root root   530 Feb  2 12:20 1038.txt
# -rwxr-xr-x 1 root root  2543 Feb  2 12:19 10394.txt
# -rwxr-xr-x 1 root root   162 Feb  2 12:21 10397.txt
# -rwxr-xr-x 1 root root   729 Feb  2 12:21 1039.txt
# -rwxr-xr-x 1 root root   904 Feb  2 12:20 10408.txt
# -rwxr-xr-x 1 root root   139 Feb  2 12:20 10416.txt
# -rwxr-xr-x 1 root root   393 Feb  2 12:21 10424.txt
# -rwxr-xr-x 1 root root   331 Feb  2 12:19 10430.txt
# -rwxr-xr-x 1 root root   992 Feb  2 12:20 10431.txt
# -rwxr-xr-x 1 root root   282 Feb  2 12:20 10443.txt
# -rwxr-xr-x 1 root root  1595 Feb  2 12:21 10446.txt
# -rwxr-xr-x 1 root root    85 Feb  2 12:20 10451.txt
# -rwxr-xr-x 1 root root    53 Feb  2 12:20 10452.txt
# -rwxr-xr-x 1 root root   872 Feb  2 12:20 10453.txt
# -rwxr-xr-x 1 root root   113 Feb  2 12:21 10468.txt
# -rwxr-xr-x 1 root root   440 Feb  2 12:20 10484.txt
# -rwxr-xr-x 1 root root   534 Feb  2 12:21 10487.txt
# -rwxr-xr-x 1 root root  1344 Feb  2 12:21 10499.txt
# -rwxr-xr-x 1 root root    85 Feb  2 12:21 10500.txt
# -rwxr-xr-x 1 root root   388 Feb  2 12:20 10525.txt
# -rwxr-xr-x 1 root root  1668 Feb  2 12:20 10534.txt
# -rwxr-xr-x 1 root root   214 Feb  2 12:19 10541.txt
# -rwxr-xr-x 1 root root   118 Feb  2 12:20 10545.txt
# -rwxr-xr-x 1 root root    53 Feb  2 12:21 10549.txt
# -rwxr-xr-x 1 root root    44 Feb  2 12:20 10551.txt
# -rwxr-xr-x 1 root root  3392 Feb  2 12:20 10552.txt
# -rwxr-xr-x 1 root root   102 Feb  2 12:20 10557.txt
# -rwxr-xr-x 1 root root  1009 Feb  2 12:19 10558.txt
# -rwxr-xr-x 1 root root  2416 Feb  2 12:20 10563.txt
# -rwxr-xr-x 1 root root   210 Feb  2 12:20 10564.txt
# -rwxr-xr-x 1 root root   465 Feb  2 12:20 10565.txt
# -rwxr-xr-x 1 root root   104 Feb  2 12:21 10568.txt
# -rwxr-xr-x 1 root root   155 Feb  2 12:20 10573.txt
# -rwxr-xr-x 1 root root   915 Feb  2 12:20 10577.txt
# -rwxr-xr-x 1 root root   105 Feb  2 12:19 10579.txt
# -rwxr-xr-x 1 root root   452 Feb  2 12:21 10582.txt
# -rwxr-xr-x 1 root root   243 Feb  2 12:20 10586.txt
# -rwxr-xr-x 1 root root   714 Feb  2 12:20 10594.txt
# -rwxr-xr-x 1 root root   436 Feb  2 12:21 105.txt
# -rwxr-xr-x 1 root root   164 Feb  2 12:20 10600.txt
# -rwxr-xr-x 1 root root   142 Feb  2 12:21 10608.txt
# -rwxr-xr-x 1 root root   317 Feb  2 12:21 1060.txt
# -rwxr-xr-x 1 root root  1112 Feb  2 12:19 10612.txt
# -rwxr-xr-x 1 root root   237 Feb  2 12:20 10616.txt
# -rwxr-xr-x 1 root root   484 Feb  2 12:21 10628.txt
# -rwxr-xr-x 1 root root  1188 Feb  2 12:20 1063.txt
# -rwxr-xr-x 1 root root   878 Feb  2 12:20 10653.txt
# -rwxr-xr-x 1 root root   188 Feb  2 12:21 10664.txt
# -rwxr-xr-x 1 root root   840 Feb  2 12:21 10670.txt
# -rwxr-xr-x 1 root root  3874 Feb  2 12:21 10679.txt
# -rwxr-xr-x 1 root root    68 Feb  2 12:19 1067.txt
# -rwxr-xr-x 1 root root    44 Feb  2 12:21 10684.txt
# -rwxr-xr-x 1 root root   188 Feb  2 12:20 10692.txt
# -rwxr-xr-x 1 root root   333 Feb  2 12:21 10695.txt
# -rwxr-xr-x 1 root root   605 Feb  2 12:20 106.txt
# -rwxr-xr-x 1 root root   663 Feb  2 12:19 10736.txt
# -rwxr-xr-x 1 root root  1816 Feb  2 12:19 10739.txt
# -rwxr-xr-x 1 root root   144 Feb  2 12:19 10749.txt
# -rwxr-xr-x 1 root root   475 Feb  2 12:21 10758.txt
# -rwxr-xr-x 1 root root   395 Feb  2 12:20 10765.txt
# -rwxr-xr-x 1 root root   173 Feb  2 12:21 10767.txt
# -rwxr-xr-x 1 root root   432 Feb  2 12:21 1076.txt
# -rwxr-xr-x 1 root root   492 Feb  2 12:20 10784.txt
# -rwxr-xr-x 1 root root  2493 Feb  2 12:21 1079.txt
# -rwxr-xr-x 1 root root   188 Feb  2 12:20 10804.txt
# -rwxr-xr-x 1 root root   288 Feb  2 12:20 10806.txt
# -rwxr-xr-x 1 root root  1227 Feb  2 12:20 10811.txt
# -rwxr-xr-x 1 root root    51 Feb  2 12:21 1081.txt
# -rwxr-xr-x 1 root root   102 Feb  2 12:19 10830.txt
# -rwxr-xr-x 1 root root    32 Feb  2 12:21 10837.txt
# -rwxr-xr-x 1 root root    95 Feb  2 12:19 10842.txt
# -rwxr-xr-x 1 root root    77 Feb  2 12:19 10848.txt
# -rwxr-xr-x 1 root root  2017 Feb  2 12:20 10855.txt
# -rwxr-xr-x 1 root root  1047 Feb  2 12:21 10872.txt
# -rwxr-xr-x 1 root root   459 Feb  2 12:20 10874.txt
# -rwxr-xr-x 1 root root  1586 Feb  2 12:21 10881.txt
# -rwxr-xr-x 1 root root   794 Feb  2 12:21 1088.txt
# -rwxr-xr-x 1 root root  2024 Feb  2 12:21 10899.txt
# -rwxr-xr-x 1 root root   267 Feb  2 12:20 10901.txt
# -rwxr-xr-x 1 root root   647 Feb  2 12:20 10906.txt
# -rwxr-xr-x 1 root root    83 Feb  2 12:20 10907.txt
# -rwxr-xr-x 1 root root   146 Feb  2 12:21 10912.txt
# -rwxr-xr-x 1 root root  1522 Feb  2 12:21 10925.txt
# -rwxr-xr-x 1 root root   657 Feb  2 12:21 1092.txt
# -rwxr-xr-x 1 root root   149 Feb  2 12:20 10940.txt
# -rwxr-xr-x 1 root root    22 Feb  2 12:21 10942.txt
# -rwxr-xr-x 1 root root   508 Feb  2 12:20 1094.txt
# -rwxr-xr-x 1 root root   417 Feb  2 12:21 10971.txt
# -rwxr-xr-x 1 root root   769 Feb  2 12:21 10976.txt
# -rwxr-xr-x 1 root root   417 Feb  2 12:21 10979.txt
# -rwxr-xr-x 1 root root   560 Feb  2 12:20 10987.txt
# -rwxr-xr-x 1 root root   560 Feb  2 12:21 10990.txt
# -rwxr-xr-x 1 root root   214 Feb  2 12:19 10992.txt
# -rwxr-xr-x 1 root root    79 Feb  2 12:21 11004.txt
# -rwxr-xr-x 1 root root    59 Feb  2 12:21 1100.txt
# -rwxr-xr-x 1 root root   729 Feb  2 12:20 11035.txt
# -rwxr-xr-x 1 root root   658 Feb  2 12:20 11059.txt
# -rwxr-xr-x 1 root root   506 Feb  2 12:20 11067.txt
# -rwxr-xr-x 1 root root    55 Feb  2 12:19 1106.txt
# -rwxr-xr-x 1 root root    67 Feb  2 12:20 11070.txt
# -rwxr-xr-x 1 root root   206 Feb  2 12:19 11076.txt
# -rwxr-xr-x 1 root root   522 Feb  2 12:21 11080.txt
# -rwxr-xr-x 1 root root  1893 Feb  2 12:21 11086.txt
# -rwxr-xr-x 1 root root    74 Feb  2 12:21 11088.txt
# -rwxr-xr-x 1 root root  1123 Feb  2 12:20 11091.txt
# -rwxr-xr-x 1 root root   185 Feb  2 12:19 11092.txt
# -rwxr-xr-x 1 root root   163 Feb  2 12:19 11100.txt
# -rwxr-xr-x 1 root root   751 Feb  2 12:20 11101.txt
# -rwxr-xr-x 1 root root   878 Feb  2 12:21 11106.txt
# -rwxr-xr-x 1 root root   265 Feb  2 12:20 11112.txt
# -rwxr-xr-x 1 root root    44 Feb  2 12:20 11115.txt
# -rwxr-xr-x 1 root root   516 Feb  2 12:21 11123.txt
# -rwxr-xr-x 1 root root   218 Feb  2 12:20 11137.txt
# -rwxr-xr-x 1 root root   209 Feb  2 12:21 11142.txt
# -rwxr-xr-x 1 root root  3530 Feb  2 12:19 11146.txt
# -rwxr-xr-x 1 root root  1166 Feb  2 12:19 11147.txt
# -rwxr-xr-x 1 root root   852 Feb  2 12:20 11148.txt
# -rwxr-xr-x 1 root root    78 Feb  2 12:21 11153.txt
# -rwxr-xr-x 1 root root   792 Feb  2 12:21 11155.txt
# -rwxr-xr-x 1 root root  1003 Feb  2 12:20 11186.txt
# -rwxr-xr-x 1 root root   215 Feb  2 12:21 11191.txt
# -rwxr-xr-x 1 root root  3662 Feb  2 12:20 11195.txt
# -rwxr-xr-x 1 root root   110 Feb  2 12:21 11198.txt
# -rwxr-xr-x 1 root root   591 Feb  2 12:21 11200.txt
# -rwxr-xr-x 1 root root  2382 Feb  2 12:20 11201.txt
# -rwxr-xr-x 1 root root    26 Feb  2 12:21 11209.txt
# -rwxr-xr-x 1 root root   140 Feb  2 12:21 1120.txt
# -rwxr-xr-x 1 root root   101 Feb  2 12:20 11214.txt
# -rwxr-xr-x 1 root root   564 Feb  2 12:20 11216.txt
# -rwxr-xr-x 1 root root   924 Feb  2 12:20 11228.txt
# -rwxr-xr-x 1 root root    47 Feb  2 12:20 11231.txt
# -rwxr-xr-x 1 root root   449 Feb  2 12:21 11244.txt
# -rwxr-xr-x 1 root root   151 Feb  2 12:20 11245.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:19 11248.txt
# -rwxr-xr-x 1 root root   290 Feb  2 12:20 1124.txt
# -rwxr-xr-x 1 root root   587 Feb  2 12:21 11264.txt
# -rwxr-xr-x 1 root root   118 Feb  2 12:21 11265.txt
# -rwxr-xr-x 1 root root   279 Feb  2 12:20 11269.txt
# -rwxr-xr-x 1 root root  2672 Feb  2 12:20 11276.txt
# -rwxr-xr-x 1 root root  2780 Feb  2 12:20 11280.txt
# -rwxr-xr-x 1 root root   206 Feb  2 12:21 11282.txt
# -rwxr-xr-x 1 root root   658 Feb  2 12:20 11295.txt
# -rwxr-xr-x 1 root root   243 Feb  2 12:19 112.txt
# -rwxr-xr-x 1 root root    70 Feb  2 12:20 11304.txt
# -rwxr-xr-x 1 root root   155 Feb  2 12:21 11307.txt
# -rwxr-xr-x 1 root root   188 Feb  2 12:21 11310.txt
# -rwxr-xr-x 1 root root   912 Feb  2 12:21 11321.txt
# -rwxr-xr-x 1 root root  1617 Feb  2 12:19 11332.txt
# -rwxr-xr-x 1 root root   267 Feb  2 12:20 11336.txt
# -rwxr-xr-x 1 root root   683 Feb  2 12:20 11340.txt
# -rwxr-xr-x 1 root root   588 Feb  2 12:20 11346.txt
# -rwxr-xr-x 1 root root   161 Feb  2 12:20 11348.txt
# -rwxr-xr-x 1 root root   149 Feb  2 12:20 11349.txt
# -rwxr-xr-x 1 root root   251 Feb  2 12:21 11358.txt
# -rwxr-xr-x 1 root root  2748 Feb  2 12:21 11363.txt
# -rwxr-xr-x 1 root root    92 Feb  2 12:20 11368.txt
# -rwxr-xr-x 1 root root   234 Feb  2 12:20 11386.txt
# -rwxr-xr-x 1 root root  1327 Feb  2 12:21 11395.txt
# -rwxr-xr-x 1 root root   453 Feb  2 12:20 1139.txt
# -rwxr-xr-x 1 root root   108 Feb  2 12:21 11401.txt
# -rwxr-xr-x 1 root root    47 Feb  2 12:21 11403.txt
# -rwxr-xr-x 1 root root   354 Feb  2 12:21 11404.txt
# -rwxr-xr-x 1 root root  3408 Feb  2 12:20 1141.txt
# -rwxr-xr-x 1 root root   159 Feb  2 12:21 11423.txt
# -rwxr-xr-x 1 root root   353 Feb  2 12:20 11433.txt
# -rwxr-xr-x 1 root root   150 Feb  2 12:19 11455.txt
# -rwxr-xr-x 1 root root   445 Feb  2 12:20 11460.txt
# -rwxr-xr-x 1 root root    81 Feb  2 12:20 11466.txt
# -rwxr-xr-x 1 root root   396 Feb  2 12:20 11476.txt
# -rwxr-xr-x 1 root root   831 Feb  2 12:21 11479.txt
# -rwxr-xr-x 1 root root   977 Feb  2 12:20 11491.txt
# -rwxr-xr-x 1 root root   393 Feb  2 12:21 11506.txt
# -rwxr-xr-x 1 root root    98 Feb  2 12:20 11507.txt
# -rwxr-xr-x 1 root root   281 Feb  2 12:20 11519.txt
# -rwxr-xr-x 1 root root    56 Feb  2 12:20 1151.txt
# -rwxr-xr-x 1 root root   541 Feb  2 12:21 11523.txt
# -rwxr-xr-x 1 root root   124 Feb  2 12:20 11542.txt
# -rwxr-xr-x 1 root root   449 Feb  2 12:20 11544.txt
# -rwxr-xr-x 1 root root    40 Feb  2 12:20 11547.txt
# -rwxr-xr-x 1 root root   336 Feb  2 12:21 11555.txt
# -rwxr-xr-x 1 root root   345 Feb  2 12:21 11567.txt
# -rwxr-xr-x 1 root root   418 Feb  2 12:20 11578.txt
# -rwxr-xr-x 1 root root   230 Feb  2 12:21 11581.txt
# -rwxr-xr-x 1 root root   336 Feb  2 12:19 11583.txt
# -rwxr-xr-x 1 root root  1731 Feb  2 12:19 11589.txt
# -rwxr-xr-x 1 root root  1877 Feb  2 12:20 1158.txt
# -rwxr-xr-x 1 root root   724 Feb  2 12:21 11590.txt
# -rwxr-xr-x 1 root root   290 Feb  2 12:20 11605.txt
# -rwxr-xr-x 1 root root    81 Feb  2 12:21 11608.txt
# -rwxr-xr-x 1 root root   158 Feb  2 12:20 11609.txt
# -rwxr-xr-x 1 root root   457 Feb  2 12:21 11614.txt
# -rwxr-xr-x 1 root root  1530 Feb  2 12:19 11623.txt
# -rwxr-xr-x 1 root root   762 Feb  2 12:21 11626.txt
# -rwxr-xr-x 1 root root  1410 Feb  2 12:20 11633.txt
# -rwxr-xr-x 1 root root   468 Feb  2 12:21 1165.txt
# -rwxr-xr-x 1 root root    74 Feb  2 12:19 11677.txt
# -rwxr-xr-x 1 root root   156 Feb  2 12:21 11680.txt
# -rwxr-xr-x 1 root root   302 Feb  2 12:21 11684.txt
# -rwxr-xr-x 1 root root   618 Feb  2 12:20 11687.txt
# -rwxr-xr-x 1 root root   314 Feb  2 12:19 11698.txt
# -rwxr-xr-x 1 root root   416 Feb  2 12:21 11702.txt
# -rwxr-xr-x 1 root root  1664 Feb  2 12:21 11708.txt
# -rwxr-xr-x 1 root root  1873 Feb  2 12:19 11710.txt
# -rwxr-xr-x 1 root root   110 Feb  2 12:21 11714.txt
# -rwxr-xr-x 1 root root   251 Feb  2 12:21 11716.txt
# -rwxr-xr-x 1 root root  2792 Feb  2 12:20 11720.txt
# -rwxr-xr-x 1 root root   257 Feb  2 12:19 11724.txt
# -rwxr-xr-x 1 root root   253 Feb  2 12:19 11729.txt
# -rwxr-xr-x 1 root root   230 Feb  2 12:19 1173.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:21 11749.txt
# -rwxr-xr-x 1 root root  1208 Feb  2 12:19 11763.txt
# -rwxr-xr-x 1 root root  3166 Feb  2 12:19 11764.txt
# -rwxr-xr-x 1 root root   409 Feb  2 12:20 11767.txt
# -rwxr-xr-x 1 root root   524 Feb  2 12:20 11796.txt
# -rwxr-xr-x 1 root root  1585 Feb  2 12:21 117.txt
# -rwxr-xr-x 1 root root   118 Feb  2 12:21 11800.txt
# -rwxr-xr-x 1 root root   140 Feb  2 12:20 11808.txt
# -rwxr-xr-x 1 root root    83 Feb  2 12:20 11811.txt
# -rwxr-xr-x 1 root root   164 Feb  2 12:21 11812.txt
# -rwxr-xr-x 1 root root   858 Feb  2 12:21 11819.txt
# -rwxr-xr-x 1 root root   177 Feb  2 12:20 11820.txt
# -rwxr-xr-x 1 root root  1030 Feb  2 12:20 11824.txt
# -rwxr-xr-x 1 root root  4888 Feb  2 12:20 11825.txt
# -rwxr-xr-x 1 root root   382 Feb  2 12:20 1182.txt
# -rwxr-xr-x 1 root root  2109 Feb  2 12:21 11832.txt
# -rwxr-xr-x 1 root root   476 Feb  2 12:19 11837.txt
# -rwxr-xr-x 1 root root  1510 Feb  2 12:20 11850.txt
# -rwxr-xr-x 1 root root   172 Feb  2 12:20 11863.txt
# -rwxr-xr-x 1 root root   318 Feb  2 12:20 11871.txt
# -rwxr-xr-x 1 root root   202 Feb  2 12:19 11881.txt
# -rwxr-xr-x 1 root root   862 Feb  2 12:20 11897.txt
# -rwxr-xr-x 1 root root   204 Feb  2 12:20 11906.txt
# -rwxr-xr-x 1 root root 14729 Feb  2 12:21 11923.txt
# -rwxr-xr-x 1 root root   167 Feb  2 12:19 11927.txt
# -rwxr-xr-x 1 root root  1818 Feb  2 12:21 11930.txt
# -rwxr-xr-x 1 root root  3060 Feb  2 12:20 1193.txt
# -rwxr-xr-x 1 root root   247 Feb  2 12:21 1194.txt
# -rwxr-xr-x 1 root root   401 Feb  2 12:19 11956.txt
# -rwxr-xr-x 1 root root   166 Feb  2 12:21 11962.txt
# -rwxr-xr-x 1 root root   249 Feb  2 12:21 11971.txt
# -rwxr-xr-x 1 root root    39 Feb  2 12:20 11979.txt
# -rwxr-xr-x 1 root root   467 Feb  2 12:20 1197.txt
# -rwxr-xr-x 1 root root    77 Feb  2 12:21 11989.txt
# -rwxr-xr-x 1 root root   231 Feb  2 12:20 11999.txt
# -rwxr-xr-x 1 root root   337 Feb  2 12:20 12002.txt
# -rwxr-xr-x 1 root root   318 Feb  2 12:20 12018.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:19 1202.txt
# -rwxr-xr-x 1 root root    67 Feb  2 12:20 12030.txt
# -rwxr-xr-x 1 root root   616 Feb  2 12:21 12038.txt
# -rwxr-xr-x 1 root root   107 Feb  2 12:20 12040.txt
# -rwxr-xr-x 1 root root   175 Feb  2 12:20 12045.txt
# -rwxr-xr-x 1 root root   109 Feb  2 12:20 12050.txt
# -rwxr-xr-x 1 root root   361 Feb  2 12:20 12051.txt
# -rwxr-xr-x 1 root root  3766 Feb  2 12:21 12054.txt
# -rwxr-xr-x 1 root root   746 Feb  2 12:20 12058.txt
# -rwxr-xr-x 1 root root   550 Feb  2 12:19 12064.txt
# -rwxr-xr-x 1 root root   384 Feb  2 12:20 12068.txt
# -rwxr-xr-x 1 root root    57 Feb  2 12:19 12071.txt
# -rwxr-xr-x 1 root root   288 Feb  2 12:19 1207.txt
# -rwxr-xr-x 1 root root   618 Feb  2 12:20 12081.txt
# -rwxr-xr-x 1 root root   982 Feb  2 12:21 12089.txt
# -rwxr-xr-x 1 root root    63 Feb  2 12:20 12090.txt
# -rwxr-xr-x 1 root root  2826 Feb  2 12:19 12091.txt
# -rwxr-xr-x 1 root root   608 Feb  2 12:21 12098.txt
# -rwxr-xr-x 1 root root   339 Feb  2 12:21 12099.txt
# -rwxr-xr-x 1 root root   233 Feb  2 12:21 1209.txt
# -rwxr-xr-x 1 root root   152 Feb  2 12:20 12120.txt
# -rwxr-xr-x 1 root root   225 Feb  2 12:21 12130.txt
# -rwxr-xr-x 1 root root   631 Feb  2 12:19 12145.txt
# -rwxr-xr-x 1 root root    35 Feb  2 12:19 12147.txt
# -rwxr-xr-x 1 root root   650 Feb  2 12:20 12152.txt
# -rwxr-xr-x 1 root root   198 Feb  2 12:19 12156.txt
# -rwxr-xr-x 1 root root   653 Feb  2 12:21 12161.txt
# -rwxr-xr-x 1 root root   429 Feb  2 12:20 12166.txt
# -rwxr-xr-x 1 root root  1989 Feb  2 12:21 12183.txt
# -rwxr-xr-x 1 root root   352 Feb  2 12:20 12188.txt
# -rwxr-xr-x 1 root root  1722 Feb  2 12:21 12190.txt
# -rwxr-xr-x 1 root root   332 Feb  2 12:20 12192.txt
# -rwxr-xr-x 1 root root   150 Feb  2 12:20 12207.txt
# -rwxr-xr-x 1 root root    31 Feb  2 12:20 12212.txt
# -rwxr-xr-x 1 root root   531 Feb  2 12:20 12215.txt
# -rwxr-xr-x 1 root root   757 Feb  2 12:20 12231.txt
# -rwxr-xr-x 1 root root    76 Feb  2 12:20 12238.txt
# -rwxr-xr-x 1 root root  2423 Feb  2 12:20 12245.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:20 12246.txt
# -rwxr-xr-x 1 root root   198 Feb  2 12:21 12271.txt
# -rwxr-xr-x 1 root root  2215 Feb  2 12:19 12272.txt
# -rwxr-xr-x 1 root root   501 Feb  2 12:21 12278.txt
# -rwxr-xr-x 1 root root   529 Feb  2 12:20 1227.txt
# -rwxr-xr-x 1 root root   287 Feb  2 12:20 12287.txt
# -rwxr-xr-x 1 root root   606 Feb  2 12:21 12289.txt
# -rwxr-xr-x 1 root root   306 Feb  2 12:20 12320.txt
# -rwxr-xr-x 1 root root    91 Feb  2 12:21 12322.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:20 12326.txt
# -rwxr-xr-x 1 root root    62 Feb  2 12:19 12331.txt
# -rwxr-xr-x 1 root root   176 Feb  2 12:20 1234.txt
# -rwxr-xr-x 1 root root  1861 Feb  2 12:19 12351.txt
# -rwxr-xr-x 1 root root   675 Feb  2 12:20 12357.txt
# -rwxr-xr-x 1 root root   882 Feb  2 12:21 12362.txt
# -rwxr-xr-x 1 root root   139 Feb  2 12:19 12372.txt
# -rwxr-xr-x 1 root root    77 Feb  2 12:20 12378.txt
# -rwxr-xr-x 1 root root   625 Feb  2 12:20 12380.txt
# -rwxr-xr-x 1 root root   107 Feb  2 12:19 12381.txt
# -rwxr-xr-x 1 root root   305 Feb  2 12:19 12387.txt
# -rwxr-xr-x 1 root root    77 Feb  2 12:20 12393.txt
# -rwxr-xr-x 1 root root  2624 Feb  2 12:21 12403.txt
# -rwxr-xr-x 1 root root   143 Feb  2 12:21 12404.txt
# -rwxr-xr-x 1 root root   682 Feb  2 12:21 12406.txt
# -rwxr-xr-x 1 root root   899 Feb  2 12:20 12413.txt
# -rwxr-xr-x 1 root root    62 Feb  2 12:19 12421.txt
# -rwxr-xr-x 1 root root   276 Feb  2 12:20 12434.txt
# -rwxr-xr-x 1 root root  1460 Feb  2 12:20 12450.txt
# -rwxr-xr-x 1 root root   612 Feb  2 12:19 12457.txt
# -rwxr-xr-x 1 root root   510 Feb  2 12:20 1245.txt
# -rwxr-xr-x 1 root root   359 Feb  2 12:20 12461.txt
# -rwxr-xr-x 1 root root   296 Feb  2 12:20 12467.txt
# -rwxr-xr-x 1 root root    29 Feb  2 12:21 12469.txt
# -rwxr-xr-x 1 root root   227 Feb  2 12:21 12471.txt
# -rwxr-xr-x 1 root root   583 Feb  2 12:21 12479.txt
# -rwxr-xr-x 1 root root     8 Feb  2 12:20 12493.txt
# -rwxr-xr-x 1 root root  1001 Feb  2 12:21 124.txt
# -rwxr-xr-x 1 root root   389 Feb  2 12:19 12517.txt
# -rwxr-xr-x 1 root root   241 Feb  2 12:21 12528.txt
# -rwxr-xr-x 1 root root  3163 Feb  2 12:20 12533.txt
# -rwxr-xr-x 1 root root    77 Feb  2 12:19 12547.txt
# -rwxr-xr-x 1 root root   380 Feb  2 12:20 12550.txt
# -rwxr-xr-x 1 root root  1717 Feb  2 12:20 12573.txt
# -rwxr-xr-x 1 root root  1382 Feb  2 12:19 12581.txt
# -rwxr-xr-x 1 root root   101 Feb  2 12:19 12585.txt
# -rwxr-xr-x 1 root root    47 Feb  2 12:20 1259.txt
# -rwxr-xr-x 1 root root    67 Feb  2 12:20 12610.txt
# -rwxr-xr-x 1 root root 19345 Feb  2 12:20 12613.txt
# -rwxr-xr-x 1 root root   671 Feb  2 12:20 12622.txt
# -rwxr-xr-x 1 root root  3975 Feb  2 12:20 12632.txt
# -rwxr-xr-x 1 root root  1200 Feb  2 12:20 12634.txt
# -rwxr-xr-x 1 root root  1674 Feb  2 12:21 12645.txt
# -rwxr-xr-x 1 root root    95 Feb  2 12:20 12646.txt
# -rwxr-xr-x 1 root root   153 Feb  2 12:20 12651.txt
# -rwxr-xr-x 1 root root   259 Feb  2 12:20 1265.txt
# -rwxr-xr-x 1 root root   382 Feb  2 12:20 12660.txt
# -rwxr-xr-x 1 root root    35 Feb  2 12:20 12667.txt
# -rwxr-xr-x 1 root root  2324 Feb  2 12:21 1266.txt
# -rwxr-xr-x 1 root root   381 Feb  2 12:20 12677.txt
# -rwxr-xr-x 1 root root   233 Feb  2 12:21 12702.txt
# -rwxr-xr-x 1 root root   424 Feb  2 12:20 12704.txt
# -rwxr-xr-x 1 root root  1396 Feb  2 12:20 12706.txt
# -rwxr-xr-x 1 root root    53 Feb  2 12:20 1270.txt
# -rwxr-xr-x 1 root root   159 Feb  2 12:19 12712.txt
# -rwxr-xr-x 1 root root   387 Feb  2 12:21 12713.txt
# -rwxr-xr-x 1 root root    71 Feb  2 12:20 12717.txt
# -rwxr-xr-x 1 root root   402 Feb  2 12:19 12720.txt
# -rwxr-xr-x 1 root root    75 Feb  2 12:19 12721.txt
# -rwxr-xr-x 1 root root    49 Feb  2 12:21 12725.txt
# -rwxr-xr-x 1 root root   344 Feb  2 12:21 12726.txt
# -rwxr-xr-x 1 root root  1704 Feb  2 12:20 12727.txt
# -rwxr-xr-x 1 root root   687 Feb  2 12:20 12732.txt
# -rwxr-xr-x 1 root root  1236 Feb  2 12:20 12735.txt
# -rwxr-xr-x 1 root root  1017 Feb  2 12:19 12739.txt
# -rwxr-xr-x 1 root root  1004 Feb  2 12:20 12740.txt
# -rwxr-xr-x 1 root root   104 Feb  2 12:20 12756.txt
# -rwxr-xr-x 1 root root   577 Feb  2 12:21 12768.txt
# -rwxr-xr-x 1 root root   798 Feb  2 12:20 12775.txt
# -rwxr-xr-x 1 root root   795 Feb  2 12:21 12776.txt
# -rwxr-xr-x 1 root root  2826 Feb  2 12:21 12792.txt
# -rwxr-xr-x 1 root root   186 Feb  2 12:21 12804.txt
# -rwxr-xr-x 1 root root   198 Feb  2 12:21 12807.txt
# -rwxr-xr-x 1 root root   845 Feb  2 12:21 12820.txt
# -rwxr-xr-x 1 root root  1810 Feb  2 12:20 12821.txt
# -rwxr-xr-x 1 root root   242 Feb  2 12:21 12826.txt
# -rwxr-xr-x 1 root root    62 Feb  2 12:21 12835.txt
# -rwxr-xr-x 1 root root   323 Feb  2 12:21 1284.txt
# -rwxr-xr-x 1 root root   107 Feb  2 12:20 12865.txt
# -rwxr-xr-x 1 root root   266 Feb  2 12:19 12870.txt
# -rwxr-xr-x 1 root root   125 Feb  2 12:21 12873.txt
# -rwxr-xr-x 1 root root   887 Feb  2 12:21 12879.txt
# -rwxr-xr-x 1 root root   674 Feb  2 12:21 12880.txt
# -rwxr-xr-x 1 root root   233 Feb  2 12:20 12882.txt
# -rwxr-xr-x 1 root root    90 Feb  2 12:19 12890.txt
# -rwxr-xr-x 1 root root   250 Feb  2 12:21 12899.txt
# -rwxr-xr-x 1 root root  1365 Feb  2 12:20 12905.txt
# -rwxr-xr-x 1 root root   110 Feb  2 12:20 1290.txt
# -rwxr-xr-x 1 root root   377 Feb  2 12:21 12915.txt
# -rwxr-xr-x 1 root root   210 Feb  2 12:20 12916.txt
# -rwxr-xr-x 1 root root   154 Feb  2 12:20 12925.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:19 12929.txt
# -rwxr-xr-x 1 root root    70 Feb  2 12:20 12944.txt
# -rwxr-xr-x 1 root root   709 Feb  2 12:21 12945.txt
# -rwxr-xr-x 1 root root    89 Feb  2 12:21 12951.txt
# -rwxr-xr-x 1 root root   320 Feb  2 12:20 12955.txt
# -rwxr-xr-x 1 root root   804 Feb  2 12:21 12961.txt
# -rwxr-xr-x 1 root root   541 Feb  2 12:20 12964.txt
# -rwxr-xr-x 1 root root   495 Feb  2 12:20 12971.txt
# -rwxr-xr-x 1 root root  3921 Feb  2 12:21 12974.txt
# -rwxr-xr-x 1 root root   152 Feb  2 12:20 12980.txt
# -rwxr-xr-x 1 root root  1607 Feb  2 12:20 12984.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:19 12999.txt
# -rwxr-xr-x 1 root root   395 Feb  2 12:21 1299.txt
# -rwxr-xr-x 1 root root   668 Feb  2 12:20 12.txt
# -rwxr-xr-x 1 root root    96 Feb  2 12:20 13005.txt
# -rwxr-xr-x 1 root root  1829 Feb  2 12:21 13007.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:20 13010.txt
# -rwxr-xr-x 1 root root    91 Feb  2 12:21 13011.txt
# -rwxr-xr-x 1 root root    83 Feb  2 12:21 13019.txt
# -rwxr-xr-x 1 root root   285 Feb  2 12:20 13026.txt
# -rwxr-xr-x 1 root root   125 Feb  2 12:20 13029.txt
# -rwxr-xr-x 1 root root  9050 Feb  2 12:20 13033.txt
# -rwxr-xr-x 1 root root  2633 Feb  2 12:20 13035.txt
# -rwxr-xr-x 1 root root   560 Feb  2 12:19 13036.txt
# -rwxr-xr-x 1 root root   264 Feb  2 12:21 13038.txt
# -rwxr-xr-x 1 root root    62 Feb  2 12:21 13040.txt
# -rwxr-xr-x 1 root root   152 Feb  2 12:21 13069.txt
# -rwxr-xr-x 1 root root   972 Feb  2 12:21 13078.txt
# -rwxr-xr-x 1 root root   167 Feb  2 12:20 13084.txt
# -rwxr-xr-x 1 root root    80 Feb  2 12:20 1308.txt
# -rwxr-xr-x 1 root root   295 Feb  2 12:20 13136.txt
# -rwxr-xr-x 1 root root  3902 Feb  2 12:19 1313.txt
# -rwxr-xr-x 1 root root   532 Feb  2 12:21 1314.txt
# -rwxr-xr-x 1 root root    21 Feb  2 12:20 13151.txt
# -rwxr-xr-x 1 root root   430 Feb  2 12:21 13153.txt
# -rwxr-xr-x 1 root root   365 Feb  2 12:19 13161.txt
# -rwxr-xr-x 1 root root  2746 Feb  2 12:19 13168.txt
# -rwxr-xr-x 1 root root   101 Feb  2 12:21 13175.txt
# -rwxr-xr-x 1 root root   439 Feb  2 12:21 13186.txt
# -rwxr-xr-x 1 root root   116 Feb  2 12:20 13188.txt
# -rwxr-xr-x 1 root root   182 Feb  2 12:21 13190.txt
# -rwxr-xr-x 1 root root   645 Feb  2 12:21 13193.txt
# -rwxr-xr-x 1 root root   554 Feb  2 12:20 13207.txt
# -rwxr-xr-x 1 root root  1746 Feb  2 12:21 1320.txt
# -rwxr-xr-x 1 root root    81 Feb  2 12:21 13216.txt
# -rwxr-xr-x 1 root root   601 Feb  2 12:21 13236.txt
# -rwxr-xr-x 1 root root   206 Feb  2 12:20 13251.txt
# -rwxr-xr-x 1 root root   283 Feb  2 12:20 13252.txt
# -rwxr-xr-x 1 root root    96 Feb  2 12:21 13260.txt
# -rwxr-xr-x 1 root root   732 Feb  2 12:20 13265.txt
# -rwxr-xr-x 1 root root   492 Feb  2 12:21 13274.txt
# -rwxr-xr-x 1 root root   206 Feb  2 12:20 13294.txt
# -rwxr-xr-x 1 root root   299 Feb  2 12:20 1329.txt
# -rwxr-xr-x 1 root root   850 Feb  2 12:20 13301.txt
# -rwxr-xr-x 1 root root    81 Feb  2 12:20 13319.txt
# -rwxr-xr-x 1 root root   308 Feb  2 12:20 13326.txt
# -rwxr-xr-x 1 root root  2471 Feb  2 12:21 1332.txt
# -rwxr-xr-x 1 root root   116 Feb  2 12:20 13335.txt
# -rwxr-xr-x 1 root root   149 Feb  2 12:21 13347.txt
# -rwxr-xr-x 1 root root   308 Feb  2 12:20 13351.txt
# -rwxr-xr-x 1 root root  1583 Feb  2 12:21 13355.txt
# -rwxr-xr-x 1 root root    38 Feb  2 12:21 1336.txt
# -rwxr-xr-x 1 root root  1052 Feb  2 12:21 13384.txt
# -rwxr-xr-x 1 root root   440 Feb  2 12:21 13408.txt
# -rwxr-xr-x 1 root root    89 Feb  2 12:19 1340.txt
# -rwxr-xr-x 1 root root  1377 Feb  2 12:19 13412.txt
# -rwxr-xr-x 1 root root  1970 Feb  2 12:20 13430.txt
# -rwxr-xr-x 1 root root   270 Feb  2 12:19 13431.txt
# -rwxr-xr-x 1 root root  1611 Feb  2 12:20 13438.txt
# -rwxr-xr-x 1 root root   110 Feb  2 12:20 13445.txt
# -rwxr-xr-x 1 root root    35 Feb  2 12:20 13455.txt
# -rwxr-xr-x 1 root root   106 Feb  2 12:20 13457.txt
# -rwxr-xr-x 1 root root   306 Feb  2 12:20 13458.txt
# -rwxr-xr-x 1 root root   407 Feb  2 12:20 1348.txt
# -rwxr-xr-x 1 root root   271 Feb  2 12:20 13495.txt
# -rwxr-xr-x 1 root root   438 Feb  2 12:21 13507.txt
# -rwxr-xr-x 1 root root  1181 Feb  2 12:21 13514.txt
# -rwxr-xr-x 1 root root   101 Feb  2 12:21 13526.txt
# -rwxr-xr-x 1 root root   978 Feb  2 12:21 13536.txt
# -rwxr-xr-x 1 root root   413 Feb  2 12:20 13541.txt
# -rwxr-xr-x 1 root root   102 Feb  2 12:20 13545.txt
# -rwxr-xr-x 1 root root   167 Feb  2 12:20 13548.txt
# -rwxr-xr-x 1 root root    38 Feb  2 12:20 13549.txt
# -rwxr-xr-x 1 root root   362 Feb  2 12:21 13552.txt
# -rwxr-xr-x 1 root root  3049 Feb  2 12:21 13558.txt
# -rwxr-xr-x 1 root root  1629 Feb  2 12:20 13559.txt
# -rwxr-xr-x 1 root root   379 Feb  2 12:20 13566.txt
# -rwxr-xr-x 1 root root   152 Feb  2 12:21 13575.txt
# -rwxr-xr-x 1 root root   361 Feb  2 12:20 1357.txt
# -rwxr-xr-x 1 root root   595 Feb  2 12:20 13584.txt
# -rwxr-xr-x 1 root root    95 Feb  2 12:19 13585.txt
# -rwxr-xr-x 1 root root   147 Feb  2 12:20 1358.txt
# -rwxr-xr-x 1 root root    76 Feb  2 12:20 13590.txt
# -rwxr-xr-x 1 root root   143 Feb  2 12:20 13592.txt
# -rwxr-xr-x 1 root root  5412 Feb  2 12:21 13599.txt
# -rwxr-xr-x 1 root root   710 Feb  2 12:20 13600.txt
# -rwxr-xr-x 1 root root   585 Feb  2 12:21 13602.txt
# -rwxr-xr-x 1 root root   250 Feb  2 12:19 13610.txt
# -rwxr-xr-x 1 root root  1048 Feb  2 12:19 13625.txt
# -rwxr-xr-x 1 root root   799 Feb  2 12:19 13627.txt
# -rwxr-xr-x 1 root root    29 Feb  2 12:19 13632.txt
# -rwxr-xr-x 1 root root  4949 Feb  2 12:20 13640.txt
# -rwxr-xr-x 1 root root   627 Feb  2 12:20 13646.txt
# -rwxr-xr-x 1 root root   431 Feb  2 12:19 13657.txt
# -rwxr-xr-x 1 root root   105 Feb  2 12:19 13660.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:20 13671.txt
# -rwxr-xr-x 1 root root   150 Feb  2 12:19 13675.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:21 13684.txt
# -rwxr-xr-x 1 root root   293 Feb  2 12:20 13686.txt
# -rwxr-xr-x 1 root root   221 Feb  2 12:20 13687.txt
# -rwxr-xr-x 1 root root   273 Feb  2 12:20 13693.txt
# -rwxr-xr-x 1 root root   455 Feb  2 12:20 13695.txt
# -rwxr-xr-x 1 root root  4409 Feb  2 12:20 1369.txt
# -rwxr-xr-x 1 root root   262 Feb  2 12:20 13703.txt
# -rwxr-xr-x 1 root root     7 Feb  2 12:20 13706.txt
# -rwxr-xr-x 1 root root  1036 Feb  2 12:21 13715.txt
# -rwxr-xr-x 1 root root   236 Feb  2 12:21 1371.txt
# -rwxr-xr-x 1 root root   495 Feb  2 12:20 13720.txt
# -rwxr-xr-x 1 root root    73 Feb  2 12:20 13728.txt
# -rwxr-xr-x 1 root root   161 Feb  2 12:21 13739.txt
# -rwxr-xr-x 1 root root   209 Feb  2 12:19 13745.txt
# -rwxr-xr-x 1 root root   165 Feb  2 12:21 13748.txt
# -rwxr-xr-x 1 root root   221 Feb  2 12:21 13759.txt
# -rwxr-xr-x 1 root root    19 Feb  2 12:21 13768.txt
# -rwxr-xr-x 1 root root   101 Feb  2 12:21 13787.txt
# -rwxr-xr-x 1 root root   123 Feb  2 12:21 1378.txt
# -rwxr-xr-x 1 root root   225 Feb  2 12:20 13790.txt
# -rwxr-xr-x 1 root root   254 Feb  2 12:19 13796.txt
# -rwxr-xr-x 1 root root   638 Feb  2 12:21 1380.txt
# -rwxr-xr-x 1 root root    20 Feb  2 12:20 1381.txt
# -rwxr-xr-x 1 root root  1355 Feb  2 12:20 13826.txt
# -rwxr-xr-x 1 root root   609 Feb  2 12:21 13835.txt
# -rwxr-xr-x 1 root root   148 Feb  2 12:20 13843.txt
# -rwxr-xr-x 1 root root   225 Feb  2 12:20 13847.txt
# -rwxr-xr-x 1 root root  3061 Feb  2 12:21 13849.txt
# -rwxr-xr-x 1 root root  5928 Feb  2 12:21 13852.txt
# -rwxr-xr-x 1 root root   332 Feb  2 12:21 13856.txt
# -rwxr-xr-x 1 root root  2054 Feb  2 12:19 13859.txt
# -rwxr-xr-x 1 root root   152 Feb  2 12:20 13866.txt
# -rwxr-xr-x 1 root root   380 Feb  2 12:20 13868.txt
# -rwxr-xr-x 1 root root   628 Feb  2 12:20 13882.txt
# -rwxr-xr-x 1 root root   173 Feb  2 12:19 13888.txt
# -rwxr-xr-x 1 root root   326 Feb  2 12:21 13890.txt
# -rwxr-xr-x 1 root root   582 Feb  2 12:21 13906.txt
# -rwxr-xr-x 1 root root   507 Feb  2 12:21 1390.txt
# -rwxr-xr-x 1 root root   105 Feb  2 12:20 13919.txt
# -rwxr-xr-x 1 root root    80 Feb  2 12:21 13921.txt
# -rwxr-xr-x 1 root root   298 Feb  2 12:21 13924.txt
# -rwxr-xr-x 1 root root   245 Feb  2 12:19 13931.txt
# -rwxr-xr-x 1 root root   121 Feb  2 12:20 13943.txt
# -rwxr-xr-x 1 root root   384 Feb  2 12:20 13946.txt
# -rwxr-xr-x 1 root root  3035 Feb  2 12:20 1394.txt
# -rwxr-xr-x 1 root root   364 Feb  2 12:21 13957.txt
# -rwxr-xr-x 1 root root    32 Feb  2 12:20 13964.txt
# -rwxr-xr-x 1 root root   409 Feb  2 12:21 13965.txt
# -rwxr-xr-x 1 root root    96 Feb  2 12:21 13966.txt
# -rwxr-xr-x 1 root root   561 Feb  2 12:21 13976.txt
# -rwxr-xr-x 1 root root   213 Feb  2 12:19 1397.txt
# -rwxr-xr-x 1 root root  1090 Feb  2 12:19 13990.txt
# -rwxr-xr-x 1 root root  3030 Feb  2 12:21 13993.txt
# -rwxr-xr-x 1 root root   290 Feb  2 12:20 13995.txt
# -rwxr-xr-x 1 root root   261 Feb  2 12:21 14004.txt
# -rwxr-xr-x 1 root root   828 Feb  2 12:20 14008.txt
# -rwxr-xr-x 1 root root   221 Feb  2 12:19 14012.txt
# -rwxr-xr-x 1 root root   260 Feb  2 12:20 14031.txt
# -rwxr-xr-x 1 root root    89 Feb  2 12:19 14035.txt
# -rwxr-xr-x 1 root root   354 Feb  2 12:20 14038.txt
# -rwxr-xr-x 1 root root   350 Feb  2 12:19 14041.txt
# -rwxr-xr-x 1 root root   119 Feb  2 12:20 14049.txt
# -rwxr-xr-x 1 root root   414 Feb  2 12:19 14059.txt
# -rwxr-xr-x 1 root root  4208 Feb  2 12:20 14061.txt
# -rwxr-xr-x 1 root root    68 Feb  2 12:20 14080.txt
# -rwxr-xr-x 1 root root   772 Feb  2 12:19 14085.txt
# -rwxr-xr-x 1 root root    77 Feb  2 12:20 14099.txt
# -rwxr-xr-x 1 root root   138 Feb  2 12:20 14102.txt
# -rwxr-xr-x 1 root root   962 Feb  2 12:20 14114.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:21 14118.txt
# -rwxr-xr-x 1 root root   275 Feb  2 12:21 14123.txt
# -rwxr-xr-x 1 root root    52 Feb  2 12:20 14125.txt
# -rwxr-xr-x 1 root root   338 Feb  2 12:19 14126.txt
# -rwxr-xr-x 1 root root    97 Feb  2 12:21 14144.txt
# -rwxr-xr-x 1 root root  1825 Feb  2 12:20 14164.txt
# -rwxr-xr-x 1 root root    11 Feb  2 12:21 14168.txt
# -rwxr-xr-x 1 root root   173 Feb  2 12:21 14169.txt
# -rwxr-xr-x 1 root root   203 Feb  2 12:21 14173.txt
# -rwxr-xr-x 1 root root   119 Feb  2 12:19 14182.txt
# -rwxr-xr-x 1 root root   386 Feb  2 12:20 14183.txt
# -rwxr-xr-x 1 root root    59 Feb  2 12:20 14198.txt
# -rwxr-xr-x 1 root root   159 Feb  2 12:19 14203.txt
# -rwxr-xr-x 1 root root   185 Feb  2 12:20 14207.txt
# -rwxr-xr-x 1 root root  1434 Feb  2 12:21 14212.txt
# -rwxr-xr-x 1 root root  3714 Feb  2 12:20 14237.txt
# -rwxr-xr-x 1 root root    43 Feb  2 12:21 14250.txt
# -rwxr-xr-x 1 root root  1029 Feb  2 12:21 14265.txt
# -rwxr-xr-x 1 root root   143 Feb  2 12:19 14266.txt
# -rwxr-xr-x 1 root root  2376 Feb  2 12:20 14267.txt
# -rwxr-xr-x 1 root root    80 Feb  2 12:19 1426.txt
# -rwxr-xr-x 1 root root  3856 Feb  2 12:19 1427.txt
# -rwxr-xr-x 1 root root    44 Feb  2 12:20 14288.txt
# -rwxr-xr-x 1 root root   552 Feb  2 12:20 1428.txt
# -rwxr-xr-x 1 root root   337 Feb  2 12:21 14291.txt
# -rwxr-xr-x 1 root root   797 Feb  2 12:20 14302.txt
# -rwxr-xr-x 1 root root   268 Feb  2 12:20 14315.txt
# -rwxr-xr-x 1 root root   191 Feb  2 12:20 14319.txt
# -rwxr-xr-x 1 root root   238 Feb  2 12:20 14332.txt
# -rwxr-xr-x 1 root root   210 Feb  2 12:20 14338.txt
# -rwxr-xr-x 1 root root    76 Feb  2 12:21 14353.txt
# -rwxr-xr-x 1 root root   345 Feb  2 12:21 14354.txt
# -rwxr-xr-x 1 root root   158 Feb  2 12:19 14358.txt
# -rwxr-xr-x 1 root root    98 Feb  2 12:19 14366.txt
# -rwxr-xr-x 1 root root    56 Feb  2 12:20 14388.txt
# -rwxr-xr-x 1 root root   656 Feb  2 12:20 14393.txt
# -rwxr-xr-x 1 root root   224 Feb  2 12:21 14407.txt
# -rwxr-xr-x 1 root root    56 Feb  2 12:20 14410.txt
# -rwxr-xr-x 1 root root   402 Feb  2 12:21 14420.txt
# -rwxr-xr-x 1 root root   389 Feb  2 12:21 14423.txt
# -rwxr-xr-x 1 root root   101 Feb  2 12:21 14441.txt
# -rwxr-xr-x 1 root root   114 Feb  2 12:20 14450.txt
# -rwxr-xr-x 1 root root  1091 Feb  2 12:21 14457.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:21 14469.txt
# -rwxr-xr-x 1 root root  3382 Feb  2 12:21 14472.txt
# -rwxr-xr-x 1 root root  1483 Feb  2 12:20 14475.txt
# -rwxr-xr-x 1 root root    97 Feb  2 12:21 14476.txt
# -rwxr-xr-x 1 root root   138 Feb  2 12:20 14480.txt
# -rwxr-xr-x 1 root root    50 Feb  2 12:20 14481.txt
# -rwxr-xr-x 1 root root  1646 Feb  2 12:20 14486.txt
# -rwxr-xr-x 1 root root   205 Feb  2 12:19 14493.txt
# -rwxr-xr-x 1 root root   509 Feb  2 12:20 14497.txt
# -rwxr-xr-x 1 root root   303 Feb  2 12:20 14498.txt
# -rwxr-xr-x 1 root root   447 Feb  2 12:20 1449.txt
# -rwxr-xr-x 1 root root    71 Feb  2 12:20 14506.txt
# -rwxr-xr-x 1 root root   541 Feb  2 12:21 14511.txt
# -rwxr-xr-x 1 root root   240 Feb  2 12:21 14515.txt
# -rwxr-xr-x 1 root root   648 Feb  2 12:21 1453.txt
# -rwxr-xr-x 1 root root    52 Feb  2 12:20 14548.txt
# -rwxr-xr-x 1 root root   201 Feb  2 12:20 14550.txt
# -rwxr-xr-x 1 root root    69 Feb  2 12:19 1455.txt
# -rwxr-xr-x 1 root root   239 Feb  2 12:21 14561.txt
# -rwxr-xr-x 1 root root   432 Feb  2 12:20 14563.txt
# -rwxr-xr-x 1 root root   289 Feb  2 12:20 14566.txt
# -rwxr-xr-x 1 root root   311 Feb  2 12:21 14568.txt
# -rwxr-xr-x 1 root root   178 Feb  2 12:21 14574.txt
# -rwxr-xr-x 1 root root  1567 Feb  2 12:20 14575.txt
# -rwxr-xr-x 1 root root  2971 Feb  2 12:20 14579.txt
# -rwxr-xr-x 1 root root  1089 Feb  2 12:20 14585.txt
# -rwxr-xr-x 1 root root  1663 Feb  2 12:20 14590.txt
# -rwxr-xr-x 1 root root    36 Feb  2 12:21 14609.txt
# -rwxr-xr-x 1 root root   106 Feb  2 12:21 14612.txt
# -rwxr-xr-x 1 root root   124 Feb  2 12:19 14616.txt
# -rwxr-xr-x 1 root root   624 Feb  2 12:20 14622.txt
# -rwxr-xr-x 1 root root   302 Feb  2 12:20 14626.txt
# -rwxr-xr-x 1 root root   847 Feb  2 12:20 14629.txt
# -rwxr-xr-x 1 root root   153 Feb  2 12:20 14633.txt
# -rwxr-xr-x 1 root root    89 Feb  2 12:20 14635.txt
# -rwxr-xr-x 1 root root   275 Feb  2 12:21 14655.txt
# -rwxr-xr-x 1 root root   246 Feb  2 12:20 14663.txt
# -rwxr-xr-x 1 root root   368 Feb  2 12:21 14669.txt
# -rwxr-xr-x 1 root root  2561 Feb  2 12:20 14670.txt
# -rwxr-xr-x 1 root root   583 Feb  2 12:20 146.txt
# -rwxr-xr-x 1 root root   104 Feb  2 12:21 14700.txt
# -rwxr-xr-x 1 root root  1239 Feb  2 12:20 14701.txt
# -rwxr-xr-x 1 root root  2674 Feb  2 12:19 1470.txt
# -rwxr-xr-x 1 root root   626 Feb  2 12:21 14716.txt
# -rwxr-xr-x 1 root root   146 Feb  2 12:20 14722.txt
# -rwxr-xr-x 1 root root   190 Feb  2 12:21 14743.txt
# -rwxr-xr-x 1 root root   277 Feb  2 12:20 14747.txt
# -rwxr-xr-x 1 root root   720 Feb  2 12:20 1474.txt
# -rwxr-xr-x 1 root root   323 Feb  2 12:20 14750.txt
# -rwxr-xr-x 1 root root  2558 Feb  2 12:21 14757.txt
# -rwxr-xr-x 1 root root   429 Feb  2 12:20 14762.txt
# -rwxr-xr-x 1 root root   338 Feb  2 12:20 14763.txt
# -rwxr-xr-x 1 root root   424 Feb  2 12:21 14768.txt
# -rwxr-xr-x 1 root root   614 Feb  2 12:19 14780.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:19 14782.txt
# -rwxr-xr-x 1 root root   342 Feb  2 12:21 14784.txt
# -rwxr-xr-x 1 root root   470 Feb  2 12:21 14787.txt
# -rwxr-xr-x 1 root root   379 Feb  2 12:20 14798.txt
# -rwxr-xr-x 1 root root   327 Feb  2 12:20 14802.txt
# -rwxr-xr-x 1 root root  1065 Feb  2 12:21 14814.txt
# -rwxr-xr-x 1 root root   655 Feb  2 12:19 14816.txt
# -rwxr-xr-x 1 root root   258 Feb  2 12:20 14827.txt
# -rwxr-xr-x 1 root root   295 Feb  2 12:20 14838.txt
# -rwxr-xr-x 1 root root   257 Feb  2 12:21 14850.txt
# -rwxr-xr-x 1 root root   802 Feb  2 12:21 14851.txt
# -rwxr-xr-x 1 root root  3040 Feb  2 12:19 14855.txt
# -rwxr-xr-x 1 root root   158 Feb  2 12:21 14860.txt
# -rwxr-xr-x 1 root root    59 Feb  2 12:20 14876.txt
# -rwxr-xr-x 1 root root   149 Feb  2 12:20 14883.txt
# -rwxr-xr-x 1 root root   110 Feb  2 12:21 14884.txt
# -rwxr-xr-x 1 root root   343 Feb  2 12:20 14887.txt
# -rwxr-xr-x 1 root root   891 Feb  2 12:20 1488.txt
# -rwxr-xr-x 1 root root    75 Feb  2 12:20 14890.txt
# -rwxr-xr-x 1 root root  4322 Feb  2 12:20 14898.txt
# -rwxr-xr-x 1 root root  1540 Feb  2 12:21 148.txt
# -rwxr-xr-x 1 root root   354 Feb  2 12:20 14905.txt
# -rwxr-xr-x 1 root root   363 Feb  2 12:20 14908.txt
# -rwxr-xr-x 1 root root    59 Feb  2 12:20 14910.txt
# -rwxr-xr-x 1 root root   137 Feb  2 12:20 14935.txt
# -rwxr-xr-x 1 root root   436 Feb  2 12:20 14936.txt
# -rwxr-xr-x 1 root root   156 Feb  2 12:20 1494.txt
# -rwxr-xr-x 1 root root   495 Feb  2 12:21 14958.txt
# -rwxr-xr-x 1 root root   495 Feb  2 12:20 14960.txt
# -rwxr-xr-x 1 root root   104 Feb  2 12:21 14994.txt
# -rwxr-xr-x 1 root root   711 Feb  2 12:20 14999.txt
# -rwxr-xr-x 1 root root   200 Feb  2 12:20 149.txt
# -rwxr-xr-x 1 root root    89 Feb  2 12:19 15009.txt
# -rwxr-xr-x 1 root root   119 Feb  2 12:20 15010.txt
# -rwxr-xr-x 1 root root    86 Feb  2 12:20 15011.txt
# -rwxr-xr-x 1 root root   787 Feb  2 12:20 1501.txt
# -rwxr-xr-x 1 root root   212 Feb  2 12:21 15027.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:21 15056.txt
# -rwxr-xr-x 1 root root   212 Feb  2 12:21 15062.txt
# -rwxr-xr-x 1 root root   149 Feb  2 12:21 15071.txt
# -rwxr-xr-x 1 root root   116 Feb  2 12:19 15083.txt
# -rwxr-xr-x 1 root root   310 Feb  2 12:21 15087.txt
# -rwxr-xr-x 1 root root    60 Feb  2 12:21 15089.txt
# -rwxr-xr-x 1 root root   170 Feb  2 12:20 150.txt
# -rwxr-xr-x 1 root root   890 Feb  2 12:20 15107.txt
# -rwxr-xr-x 1 root root   312 Feb  2 12:20 15110.txt
# -rwxr-xr-x 1 root root   304 Feb  2 12:20 15120.txt
# -rwxr-xr-x 1 root root   166 Feb  2 12:21 15125.txt
# -rwxr-xr-x 1 root root   507 Feb  2 12:20 15138.txt
# -rwxr-xr-x 1 root root    98 Feb  2 12:21 15143.txt
# -rwxr-xr-x 1 root root  4045 Feb  2 12:19 15170.txt
# -rwxr-xr-x 1 root root   272 Feb  2 12:20 15192.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:20 15193.txt
# -rwxr-xr-x 1 root root   429 Feb  2 12:20 15194.txt
# -rwxr-xr-x 1 root root    50 Feb  2 12:21 15199.txt
# -rwxr-xr-x 1 root root   932 Feb  2 12:21 15201.txt
# -rwxr-xr-x 1 root root   564 Feb  2 12:19 15208.txt
# -rwxr-xr-x 1 root root    62 Feb  2 12:21 15218.txt
# -rwxr-xr-x 1 root root   968 Feb  2 12:20 1521.txt
# -rwxr-xr-x 1 root root   388 Feb  2 12:21 15220.txt
# -rwxr-xr-x 1 root root   536 Feb  2 12:20 15227.txt
# -rwxr-xr-x 1 root root  4002 Feb  2 12:20 15232.txt
# -rwxr-xr-x 1 root root   251 Feb  2 12:20 15235.txt
# -rwxr-xr-x 1 root root   213 Feb  2 12:20 15239.txt
# -rwxr-xr-x 1 root root   128 Feb  2 12:21 15250.txt
# -rwxr-xr-x 1 root root  1140 Feb  2 12:21 15264.txt
# -rwxr-xr-x 1 root root   146 Feb  2 12:21 15266.txt
# -rwxr-xr-x 1 root root   995 Feb  2 12:20 15277.txt
# -rwxr-xr-x 1 root root   413 Feb  2 12:20 15278.txt
# -rwxr-xr-x 1 root root   437 Feb  2 12:21 15279.txt
# -rwxr-xr-x 1 root root   296 Feb  2 12:21 15283.txt
# -rwxr-xr-x 1 root root   220 Feb  2 12:21 1528.txt
# -rwxr-xr-x 1 root root   260 Feb  2 12:20 15291.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:21 15293.txt
# -rwxr-xr-x 1 root root   697 Feb  2 12:21 15314.txt
# -rwxr-xr-x 1 root root   168 Feb  2 12:20 1531.txt
# -rwxr-xr-x 1 root root   206 Feb  2 12:20 15328.txt
# -rwxr-xr-x 1 root root   463 Feb  2 12:20 15329.txt
# -rwxr-xr-x 1 root root   367 Feb  2 12:20 15330.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:20 15332.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:19 15334.txt
# -rwxr-xr-x 1 root root    56 Feb  2 12:20 15347.txt
# -rwxr-xr-x 1 root root   189 Feb  2 12:20 1534.txt
# -rwxr-xr-x 1 root root   418 Feb  2 12:20 15358.txt
# -rwxr-xr-x 1 root root   329 Feb  2 12:20 15365.txt
# -rwxr-xr-x 1 root root  2589 Feb  2 12:19 1537.txt
# -rwxr-xr-x 1 root root  1020 Feb  2 12:20 15382.txt
# -rwxr-xr-x 1 root root   690 Feb  2 12:21 15390.txt
# -rwxr-xr-x 1 root root   459 Feb  2 12:21 15394.txt
# -rwxr-xr-x 1 root root   405 Feb  2 12:20 15396.txt
# -rwxr-xr-x 1 root root   402 Feb  2 12:20 15398.txt
# -rwxr-xr-x 1 root root   152 Feb  2 12:19 15404.txt
# -rwxr-xr-x 1 root root   554 Feb  2 12:20 15407.txt
# -rwxr-xr-x 1 root root    90 Feb  2 12:19 15416.txt
# -rwxr-xr-x 1 root root    76 Feb  2 12:21 15422.txt
# -rwxr-xr-x 1 root root   259 Feb  2 12:21 15431.txt
# -rwxr-xr-x 1 root root   278 Feb  2 12:21 15445.txt
# -rwxr-xr-x 1 root root   752 Feb  2 12:21 15452.txt
# -rwxr-xr-x 1 root root   192 Feb  2 12:21 15453.txt
# -rwxr-xr-x 1 root root   896 Feb  2 12:19 15454.txt
# -rwxr-xr-x 1 root root    41 Feb  2 12:20 15457.txt
# -rwxr-xr-x 1 root root   127 Feb  2 12:19 15470.txt
# -rwxr-xr-x 1 root root  5476 Feb  2 12:20 15472.txt
# -rwxr-xr-x 1 root root   292 Feb  2 12:21 15475.txt
# -rwxr-xr-x 1 root root   134 Feb  2 12:20 15476.txt
# -rwxr-xr-x 1 root root   372 Feb  2 12:21 15477.txt
# -rwxr-xr-x 1 root root  1412 Feb  2 12:21 15498.txt
# -rwxr-xr-x 1 root root   857 Feb  2 12:20 15503.txt
# -rwxr-xr-x 1 root root  1130 Feb  2 12:20 15504.txt
# -rwxr-xr-x 1 root root  4666 Feb  2 12:20 15505.txt
# -rwxr-xr-x 1 root root   763 Feb  2 12:21 15509.txt
# -rwxr-xr-x 1 root root  1343 Feb  2 12:20 15510.txt
# -rwxr-xr-x 1 root root   232 Feb  2 12:21 15513.txt
# -rwxr-xr-x 1 root root   773 Feb  2 12:21 15524.txt
# -rwxr-xr-x 1 root root   814 Feb  2 12:20 15546.txt
# -rwxr-xr-x 1 root root   219 Feb  2 12:20 1554.txt
# -rwxr-xr-x 1 root root    32 Feb  2 12:20 15556.txt
# -rwxr-xr-x 1 root root  2205 Feb  2 12:19 15558.txt
# -rwxr-xr-x 1 root root   854 Feb  2 12:20 1556.txt
# -rwxr-xr-x 1 root root   675 Feb  2 12:21 15573.txt
# -rwxr-xr-x 1 root root    56 Feb  2 12:20 15576.txt
# -rwxr-xr-x 1 root root  1462 Feb  2 12:21 15590.txt
# -rwxr-xr-x 1 root root   152 Feb  2 12:21 15599.txt
# -rwxr-xr-x 1 root root  1088 Feb  2 12:20 15624.txt
# -rwxr-xr-x 1 root root    88 Feb  2 12:21 15639.txt
# -rwxr-xr-x 1 root root   286 Feb  2 12:21 15646.txt
# -rwxr-xr-x 1 root root   451 Feb  2 12:20 15654.txt
# -rwxr-xr-x 1 root root  2680 Feb  2 12:20 15657.txt
# -rwxr-xr-x 1 root root   564 Feb  2 12:19 15662.txt
# -rwxr-xr-x 1 root root    19 Feb  2 12:20 15668.txt
# -rwxr-xr-x 1 root root  1140 Feb  2 12:21 15672.txt
# -rwxr-xr-x 1 root root   372 Feb  2 12:20 15674.txt
# -rwxr-xr-x 1 root root   137 Feb  2 12:21 15675.txt
# -rwxr-xr-x 1 root root   104 Feb  2 12:20 15688.txt
# -rwxr-xr-x 1 root root   246 Feb  2 12:19 15691.txt
# -rwxr-xr-x 1 root root   393 Feb  2 12:21 15703.txt
# -rwxr-xr-x 1 root root    64 Feb  2 12:21 15710.txt
# -rwxr-xr-x 1 root root   794 Feb  2 12:21 15717.txt
# -rwxr-xr-x 1 root root   326 Feb  2 12:20 1571.txt
# -rwxr-xr-x 1 root root   228 Feb  2 12:20 15723.txt
# -rwxr-xr-x 1 root root   162 Feb  2 12:20 15730.txt
# -rwxr-xr-x 1 root root   394 Feb  2 12:21 15767.txt
# -rwxr-xr-x 1 root root  5537 Feb  2 12:20 15769.txt
# -rwxr-xr-x 1 root root   227 Feb  2 12:21 15775.txt
# -rwxr-xr-x 1 root root   271 Feb  2 12:20 15779.txt
# -rwxr-xr-x 1 root root   891 Feb  2 12:21 15784.txt
# -rwxr-xr-x 1 root root   236 Feb  2 12:21 15796.txt
# -rwxr-xr-x 1 root root  1504 Feb  2 12:21 1579.txt
# -rwxr-xr-x 1 root root   483 Feb  2 12:20 157.txt
# -rwxr-xr-x 1 root root   825 Feb  2 12:19 15809.txt
# -rwxr-xr-x 1 root root  3212 Feb  2 12:20 15847.txt
# -rwxr-xr-x 1 root root   123 Feb  2 12:19 15858.txt
# -rwxr-xr-x 1 root root   128 Feb  2 12:20 15861.txt
# -rwxr-xr-x 1 root root   484 Feb  2 12:20 1586.txt
# -rwxr-xr-x 1 root root   242 Feb  2 12:21 15891.txt
# -rwxr-xr-x 1 root root  1630 Feb  2 12:20 15892.txt
# -rwxr-xr-x 1 root root   364 Feb  2 12:19 15894.txt
# -rwxr-xr-x 1 root root   111 Feb  2 12:20 15900.txt
# -rwxr-xr-x 1 root root   999 Feb  2 12:21 15902.txt
# -rwxr-xr-x 1 root root   610 Feb  2 12:21 15903.txt
# -rwxr-xr-x 1 root root   550 Feb  2 12:20 15907.txt
# -rwxr-xr-x 1 root root    70 Feb  2 12:20 15911.txt
# -rwxr-xr-x 1 root root   378 Feb  2 12:21 15914.txt
# -rwxr-xr-x 1 root root  4807 Feb  2 12:21 15919.txt
# -rwxr-xr-x 1 root root   194 Feb  2 12:19 15929.txt
# -rwxr-xr-x 1 root root  2252 Feb  2 12:19 15935.txt
# -rwxr-xr-x 1 root root   158 Feb  2 12:20 15943.txt
# -rwxr-xr-x 1 root root   278 Feb  2 12:19 15946.txt
# -rwxr-xr-x 1 root root   535 Feb  2 12:21 1594.txt
# -rwxr-xr-x 1 root root  2481 Feb  2 12:21 15952.txt
# -rwxr-xr-x 1 root root   307 Feb  2 12:20 15961.txt
# -rwxr-xr-x 1 root root   219 Feb  2 12:20 15963.txt
# -rwxr-xr-x 1 root root    13 Feb  2 12:21 15972.txt
# -rwxr-xr-x 1 root root   204 Feb  2 12:21 1598.txt
# -rwxr-xr-x 1 root root  1532 Feb  2 12:20 15991.txt
# -rwxr-xr-x 1 root root   310 Feb  2 12:21 16019.txt
# -rwxr-xr-x 1 root root   421 Feb  2 12:20 16026.txt
# -rwxr-xr-x 1 root root   229 Feb  2 12:21 16035.txt
# -rwxr-xr-x 1 root root    43 Feb  2 12:21 16036.txt
# -rwxr-xr-x 1 root root  2552 Feb  2 12:21 16038.txt
# -rwxr-xr-x 1 root root   432 Feb  2 12:20 16042.txt
# -rwxr-xr-x 1 root root   505 Feb  2 12:20 16049.txt
# -rwxr-xr-x 1 root root  2334 Feb  2 12:20 1604.txt
# -rwxr-xr-x 1 root root    33 Feb  2 12:19 16059.txt
# -rwxr-xr-x 1 root root   183 Feb  2 12:21 16061.txt
# -rwxr-xr-x 1 root root   736 Feb  2 12:19 1606.txt
# -rwxr-xr-x 1 root root    47 Feb  2 12:20 16070.txt
# -rwxr-xr-x 1 root root  4129 Feb  2 12:20 16074.txt
# -rwxr-xr-x 1 root root   136 Feb  2 12:20 16080.txt
# -rwxr-xr-x 1 root root   172 Feb  2 12:20 1609.txt
# -rwxr-xr-x 1 root root    95 Feb  2 12:19 16109.txt
# -rwxr-xr-x 1 root root  1189 Feb  2 12:21 1610.txt
# -rwxr-xr-x 1 root root   533 Feb  2 12:20 16117.txt
# -rwxr-xr-x 1 root root  1415 Feb  2 12:21 16121.txt
# -rwxr-xr-x 1 root root    41 Feb  2 12:20 16135.txt
# -rwxr-xr-x 1 root root   114 Feb  2 12:20 16138.txt
# -rwxr-xr-x 1 root root   163 Feb  2 12:21 16142.txt
# -rwxr-xr-x 1 root root   572 Feb  2 12:20 16148.txt
# -rwxr-xr-x 1 root root   725 Feb  2 12:19 16149.txt
# -rwxr-xr-x 1 root root   472 Feb  2 12:19 1615.txt
# -rwxr-xr-x 1 root root    59 Feb  2 12:21 16160.txt
# -rwxr-xr-x 1 root root  2195 Feb  2 12:21 16173.txt
# -rwxr-xr-x 1 root root   368 Feb  2 12:20 16177.txt
# -rwxr-xr-x 1 root root   609 Feb  2 12:19 16178.txt
# -rwxr-xr-x 1 root root   134 Feb  2 12:21 16179.txt
# -rwxr-xr-x 1 root root  1312 Feb  2 12:19 16186.txt
# -rwxr-xr-x 1 root root    35 Feb  2 12:21 16193.txt
# -rwxr-xr-x 1 root root  1502 Feb  2 12:20 16194.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:19 16197.txt
# -rwxr-xr-x 1 root root  1293 Feb  2 12:19 16199.txt
# -rwxr-xr-x 1 root root  2318 Feb  2 12:21 16200.txt
# ...
# -rwxr-xr-x 1 root root    82 Feb  2 12:20 7953.txt
# -rwxr-xr-x 1 root root   943 Feb  2 12:21 7958.txt
# -rwxr-xr-x 1 root root    77 Feb  2 12:21 7961.txt
# -rwxr-xr-x 1 root root  1522 Feb  2 12:21 7962.txt
# -rwxr-xr-x 1 root root   134 Feb  2 12:19 7971.txt
# -rwxr-xr-x 1 root root   101 Feb  2 12:20 7976.txt
# -rwxr-xr-x 1 root root  3835 Feb  2 12:20 7985.txt
# -rwxr-xr-x 1 root root   709 Feb  2 12:20 7989.txt
# -rwxr-xr-x 1 root root    65 Feb  2 12:20 7995.txt
# -rwxr-xr-x 1 root root   394 Feb  2 12:21 7999.txt
# -rwxr-xr-x 1 root root   160 Feb  2 12:20 8001.txt
# -rwxr-xr-x 1 root root    53 Feb  2 12:19 8006.txt
# -rwxr-xr-x 1 root root   562 Feb  2 12:21 8009.txt
# -rwxr-xr-x 1 root root   250 Feb  2 12:21 8010.txt
# -rwxr-xr-x 1 root root  2736 Feb  2 12:19 8011.txt
# -rwxr-xr-x 1 root root  1108 Feb  2 12:20 8025.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:20 8038.txt
# -rwxr-xr-x 1 root root   289 Feb  2 12:21 8043.txt
# -rwxr-xr-x 1 root root   385 Feb  2 12:20 8057.txt
# -rwxr-xr-x 1 root root   239 Feb  2 12:21 8066.txt
# -rwxr-xr-x 1 root root   557 Feb  2 12:21 8084.txt
# -rwxr-xr-x 1 root root  2143 Feb  2 12:20 8086.txt
# -rwxr-xr-x 1 root root    62 Feb  2 12:19 8087.txt
# -rwxr-xr-x 1 root root  1590 Feb  2 12:20 808.txt
# -rwxr-xr-x 1 root root   417 Feb  2 12:20 8099.txt
# -rwxr-xr-x 1 root root   640 Feb  2 12:21 8115.txt
# -rwxr-xr-x 1 root root   191 Feb  2 12:19 8125.txt
# -rwxr-xr-x 1 root root    68 Feb  2 12:21 8126.txt
# -rwxr-xr-x 1 root root   221 Feb  2 12:21 8127.txt
# -rwxr-xr-x 1 root root   190 Feb  2 12:21 8128.txt
# -rwxr-xr-x 1 root root   262 Feb  2 12:20 8131.txt
# -rwxr-xr-x 1 root root   355 Feb  2 12:21 813.txt
# -rwxr-xr-x 1 root root   580 Feb  2 12:19 8141.txt
# -rwxr-xr-x 1 root root  1451 Feb  2 12:21 8145.txt
# -rwxr-xr-x 1 root root   255 Feb  2 12:21 8156.txt
# -rwxr-xr-x 1 root root  3251 Feb  2 12:20 8163.txt
# -rwxr-xr-x 1 root root    80 Feb  2 12:19 8171.txt
# -rwxr-xr-x 1 root root   329 Feb  2 12:20 8186.txt
# -rwxr-xr-x 1 root root    38 Feb  2 12:21 8187.txt
# -rwxr-xr-x 1 root root   693 Feb  2 12:20 8196.txt
# -rwxr-xr-x 1 root root    94 Feb  2 12:20 819.txt
# -rwxr-xr-x 1 root root   611 Feb  2 12:19 8206.txt
# -rwxr-xr-x 1 root root    98 Feb  2 12:20 8221.txt
# -rwxr-xr-x 1 root root   449 Feb  2 12:21 8222.txt
# -rwxr-xr-x 1 root root   309 Feb  2 12:19 8224.txt
# -rwxr-xr-x 1 root root   361 Feb  2 12:21 8225.txt
# -rwxr-xr-x 1 root root  2783 Feb  2 12:19 8231.txt
# -rwxr-xr-x 1 root root    17 Feb  2 12:21 8239.txt
# -rwxr-xr-x 1 root root   188 Feb  2 12:20 8245.txt
# -rwxr-xr-x 1 root root   644 Feb  2 12:20 8264.txt
# -rwxr-xr-x 1 root root   102 Feb  2 12:20 826.txt
# -rwxr-xr-x 1 root root   355 Feb  2 12:20 8271.txt
# -rwxr-xr-x 1 root root   126 Feb  2 12:21 8286.txt
# -rwxr-xr-x 1 root root   191 Feb  2 12:20 8292.txt
# -rwxr-xr-x 1 root root  2347 Feb  2 12:21 8301.txt
# -rwxr-xr-x 1 root root   668 Feb  2 12:19 8309.txt
# -rwxr-xr-x 1 root root   199 Feb  2 12:19 8311.txt
# -rwxr-xr-x 1 root root   380 Feb  2 12:20 8316.txt
# -rwxr-xr-x 1 root root   405 Feb  2 12:20 831.txt
# -rwxr-xr-x 1 root root    86 Feb  2 12:20 8324.txt
# -rwxr-xr-x 1 root root    65 Feb  2 12:20 832.txt
# -rwxr-xr-x 1 root root    26 Feb  2 12:20 8338.txt
# -rwxr-xr-x 1 root root   259 Feb  2 12:21 8342.txt
# -rwxr-xr-x 1 root root   716 Feb  2 12:20 8344.txt
# -rwxr-xr-x 1 root root   118 Feb  2 12:21 8359.txt
# -rwxr-xr-x 1 root root   434 Feb  2 12:20 8366.txt
# -rwxr-xr-x 1 root root  1761 Feb  2 12:20 8368.txt
# -rwxr-xr-x 1 root root   129 Feb  2 12:21 8369.txt
# -rwxr-xr-x 1 root root  4238 Feb  2 12:19 8370.txt
# -rwxr-xr-x 1 root root   356 Feb  2 12:20 8373.txt
# -rwxr-xr-x 1 root root   197 Feb  2 12:20 8380.txt
# -rwxr-xr-x 1 root root   114 Feb  2 12:19 8385.txt
# -rwxr-xr-x 1 root root  1148 Feb  2 12:21 8394.txt
# -rwxr-xr-x 1 root root  2507 Feb  2 12:20 8396.txt
# -rwxr-xr-x 1 root root   167 Feb  2 12:21 83.txt
# -rwxr-xr-x 1 root root    59 Feb  2 12:21 8413.txt
# -rwxr-xr-x 1 root root   116 Feb  2 12:21 8429.txt
# -rwxr-xr-x 1 root root    30 Feb  2 12:21 8435.txt
# -rwxr-xr-x 1 root root   434 Feb  2 12:20 8440.txt
# -rwxr-xr-x 1 root root   919 Feb  2 12:20 8444.txt
# -rwxr-xr-x 1 root root   733 Feb  2 12:20 8445.txt
# -rwxr-xr-x 1 root root   320 Feb  2 12:20 8454.txt
# -rwxr-xr-x 1 root root   957 Feb  2 12:20 8465.txt
# -rwxr-xr-x 1 root root    53 Feb  2 12:21 846.txt
# -rwxr-xr-x 1 root root  1769 Feb  2 12:21 8475.txt
# -rwxr-xr-x 1 root root    90 Feb  2 12:20 8479.txt
# -rwxr-xr-x 1 root root   826 Feb  2 12:21 8481.txt
# -rwxr-xr-x 1 root root   671 Feb  2 12:20 8494.txt
# -rwxr-xr-x 1 root root   884 Feb  2 12:20 8495.txt
# -rwxr-xr-x 1 root root   865 Feb  2 12:20 8502.txt
# -rwxr-xr-x 1 root root   149 Feb  2 12:20 8504.txt
# -rwxr-xr-x 1 root root   320 Feb  2 12:19 8505.txt
# -rwxr-xr-x 1 root root    65 Feb  2 12:19 8509.txt
# -rwxr-xr-x 1 root root  1227 Feb  2 12:20 8516.txt
# -rwxr-xr-x 1 root root  3411 Feb  2 12:19 8556.txt
# -rwxr-xr-x 1 root root   393 Feb  2 12:20 8563.txt
# -rwxr-xr-x 1 root root   181 Feb  2 12:20 8567.txt
# -rwxr-xr-x 1 root root  2333 Feb  2 12:21 8569.txt
# -rwxr-xr-x 1 root root   166 Feb  2 12:20 8575.txt
# -rwxr-xr-x 1 root root   131 Feb  2 12:20 8579.txt
# -rwxr-xr-x 1 root root   395 Feb  2 12:21 8581.txt
# -rwxr-xr-x 1 root root   422 Feb  2 12:20 8586.txt
# -rwxr-xr-x 1 root root   244 Feb  2 12:19 8597.txt
# -rwxr-xr-x 1 root root    55 Feb  2 12:21 8607.txt
# -rwxr-xr-x 1 root root   354 Feb  2 12:20 8612.txt
# -rwxr-xr-x 1 root root   128 Feb  2 12:20 8634.txt
# -rwxr-xr-x 1 root root    77 Feb  2 12:20 8648.txt
# -rwxr-xr-x 1 root root   699 Feb  2 12:21 8652.txt
# -rwxr-xr-x 1 root root   188 Feb  2 12:19 8662.txt
# -rwxr-xr-x 1 root root   297 Feb  2 12:21 8690.txt
# -rwxr-xr-x 1 root root   103 Feb  2 12:20 8697.txt
# -rwxr-xr-x 1 root root   406 Feb  2 12:21 8709.txt
# -rwxr-xr-x 1 root root    53 Feb  2 12:21 8712.txt
# -rwxr-xr-x 1 root root  1588 Feb  2 12:19 8718.txt
# -rwxr-xr-x 1 root root   827 Feb  2 12:21 871.txt
# -rwxr-xr-x 1 root root   588 Feb  2 12:19 8722.txt
# -rwxr-xr-x 1 root root  2162 Feb  2 12:21 8734.txt
# -rwxr-xr-x 1 root root    83 Feb  2 12:20 8743.txt
# -rwxr-xr-x 1 root root   259 Feb  2 12:20 8749.txt
# -rwxr-xr-x 1 root root   186 Feb  2 12:20 874.txt
# -rwxr-xr-x 1 root root    68 Feb  2 12:21 8754.txt
# -rwxr-xr-x 1 root root   610 Feb  2 12:20 8770.txt
# -rwxr-xr-x 1 root root   355 Feb  2 12:20 8772.txt
# -rwxr-xr-x 1 root root   130 Feb  2 12:20 8775.txt
# -rwxr-xr-x 1 root root   724 Feb  2 12:21 8790.txt
# -rwxr-xr-x 1 root root   123 Feb  2 12:21 8794.txt
# -rwxr-xr-x 1 root root   383 Feb  2 12:20 8798.txt
# -rwxr-xr-x 1 root root   132 Feb  2 12:20 8810.txt
# -rwxr-xr-x 1 root root   411 Feb  2 12:20 8812.txt
# -rwxr-xr-x 1 root root   920 Feb  2 12:20 8815.txt
# -rwxr-xr-x 1 root root   168 Feb  2 12:20 8829.txt
# -rwxr-xr-x 1 root root  1860 Feb  2 12:20 8835.txt
# -rwxr-xr-x 1 root root    78 Feb  2 12:21 8847.txt
# -rwxr-xr-x 1 root root   107 Feb  2 12:19 8852.txt
# -rwxr-xr-x 1 root root   185 Feb  2 12:20 8857.txt
# -rwxr-xr-x 1 root root   183 Feb  2 12:20 8859.txt
# -rwxr-xr-x 1 root root   326 Feb  2 12:21 8861.txt
# -rwxr-xr-x 1 root root   106 Feb  2 12:21 8874.txt
# -rwxr-xr-x 1 root root    78 Feb  2 12:21 8883.txt
# -rwxr-xr-x 1 root root    62 Feb  2 12:20 8884.txt
# -rwxr-xr-x 1 root root   308 Feb  2 12:20 8887.txt
# -rwxr-xr-x 1 root root  1842 Feb  2 12:20 8896.txt
# -rwxr-xr-x 1 root root  1095 Feb  2 12:21 8898.txt
# -rwxr-xr-x 1 root root   784 Feb  2 12:21 8904.txt
# -rwxr-xr-x 1 root root  1080 Feb  2 12:21 8907.txt
# -rwxr-xr-x 1 root root  1968 Feb  2 12:21 8915.txt
# -rwxr-xr-x 1 root root  1301 Feb  2 12:20 8920.txt
# -rwxr-xr-x 1 root root   103 Feb  2 12:21 8927.txt
# -rwxr-xr-x 1 root root   224 Feb  2 12:20 8943.txt
# -rwxr-xr-x 1 root root  1676 Feb  2 12:21 8948.txt
# -rwxr-xr-x 1 root root   152 Feb  2 12:21 8961.txt
# -rwxr-xr-x 1 root root    95 Feb  2 12:20 8969.txt
# -rwxr-xr-x 1 root root  1316 Feb  2 12:19 8980.txt
# -rwxr-xr-x 1 root root    71 Feb  2 12:20 8983.txt
# -rwxr-xr-x 1 root root   179 Feb  2 12:20 8985.txt
# -rwxr-xr-x 1 root root   473 Feb  2 12:20 8992.txt
# -rwxr-xr-x 1 root root  2581 Feb  2 12:20 8996.txt
# -rwxr-xr-x 1 root root   119 Feb  2 12:20 8999.txt
# -rwxr-xr-x 1 root root   670 Feb  2 12:21 9002.txt
# -rwxr-xr-x 1 root root    98 Feb  2 12:20 9009.txt
# -rwxr-xr-x 1 root root   184 Feb  2 12:21 9012.txt
# -rwxr-xr-x 1 root root  2373 Feb  2 12:20 9013.txt
# -rwxr-xr-x 1 root root    44 Feb  2 12:20 9024.txt
# -rwxr-xr-x 1 root root   268 Feb  2 12:20 9031.txt
# -rwxr-xr-x 1 root root   167 Feb  2 12:19 9032.txt
# -rwxr-xr-x 1 root root   104 Feb  2 12:19 9040.txt
# -rwxr-xr-x 1 root root   144 Feb  2 12:21 9055.txt
# -rwxr-xr-x 1 root root   545 Feb  2 12:19 9056.txt
# -rwxr-xr-x 1 root root   170 Feb  2 12:21 9077.txt
# -rwxr-xr-x 1 root root    56 Feb  2 12:19 9082.txt
# -rwxr-xr-x 1 root root   390 Feb  2 12:20 9086.txt
# -rwxr-xr-x 1 root root   496 Feb  2 12:19 908.txt
# -rwxr-xr-x 1 root root   156 Feb  2 12:19 9090.txt
# -rwxr-xr-x 1 root root   773 Feb  2 12:20 9096.txt
# -rwxr-xr-x 1 root root   114 Feb  2 12:21 9118.txt
# -rwxr-xr-x 1 root root   205 Feb  2 12:21 9119.txt
# -rwxr-xr-x 1 root root   164 Feb  2 12:19 9129.txt
# -rwxr-xr-x 1 root root   917 Feb  2 12:19 9130.txt
# -rwxr-xr-x 1 root root   865 Feb  2 12:21 9132.txt
# -rwxr-xr-x 1 root root    72 Feb  2 12:20 9134.txt
# -rwxr-xr-x 1 root root   335 Feb  2 12:20 9137.txt
# -rwxr-xr-x 1 root root   704 Feb  2 12:21 9141.txt
# -rwxr-xr-x 1 root root   181 Feb  2 12:20 9151.txt
# -rwxr-xr-x 1 root root   331 Feb  2 12:20 9152.txt
# -rwxr-xr-x 1 root root   101 Feb  2 12:20 9157.txt
# -rwxr-xr-x 1 root root   140 Feb  2 12:19 9165.txt
# -rwxr-xr-x 1 root root   323 Feb  2 12:20 9172.txt
# -rwxr-xr-x 1 root root   306 Feb  2 12:21 9195.txt
# -rwxr-xr-x 1 root root   563 Feb  2 12:21 9200.txt
# -rwxr-xr-x 1 root root   599 Feb  2 12:19 9202.txt
# -rwxr-xr-x 1 root root   276 Feb  2 12:19 921.txt
# -rwxr-xr-x 1 root root   620 Feb  2 12:20 9227.txt
# -rwxr-xr-x 1 root root  1505 Feb  2 12:19 9229.txt
# -rwxr-xr-x 1 root root   152 Feb  2 12:20 9231.txt
# -rwxr-xr-x 1 root root  1188 Feb  2 12:19 9233.txt
# -rwxr-xr-x 1 root root  1341 Feb  2 12:20 9239.txt
# -rwxr-xr-x 1 root root   978 Feb  2 12:20 9248.txt
# -rwxr-xr-x 1 root root   121 Feb  2 12:19 9258.txt
# -rwxr-xr-x 1 root root   173 Feb  2 12:20 9259.txt
# -rwxr-xr-x 1 root root  1158 Feb  2 12:20 9278.txt
# -rwxr-xr-x 1 root root    47 Feb  2 12:21 9288.txt
# -rwxr-xr-x 1 root root    20 Feb  2 12:21 9293.txt
# -rwxr-xr-x 1 root root    66 Feb  2 12:21 9300.txt
# -rwxr-xr-x 1 root root   145 Feb  2 12:20 9309.txt
# -rwxr-xr-x 1 root root   283 Feb  2 12:20 9312.txt
# -rwxr-xr-x 1 root root   698 Feb  2 12:19 9325.txt
# -rwxr-xr-x 1 root root  2185 Feb  2 12:21 9331.txt
# -rwxr-xr-x 1 root root   455 Feb  2 12:20 9335.txt
# -rwxr-xr-x 1 root root   498 Feb  2 12:21 9338.txt
# -rwxr-xr-x 1 root root    28 Feb  2 12:20 9352.txt
# -rwxr-xr-x 1 root root   149 Feb  2 12:19 9358.txt
# -rwxr-xr-x 1 root root   177 Feb  2 12:21 9359.txt
# -rwxr-xr-x 1 root root   107 Feb  2 12:19 936.txt
# -rwxr-xr-x 1 root root   128 Feb  2 12:21 9371.txt
# -rwxr-xr-x 1 root root  2364 Feb  2 12:20 9377.txt
# -rwxr-xr-x 1 root root   167 Feb  2 12:20 9378.txt
# -rwxr-xr-x 1 root root   618 Feb  2 12:20 937.txt
# -rwxr-xr-x 1 root root  3915 Feb  2 12:20 9380.txt
# -rwxr-xr-x 1 root root   168 Feb  2 12:20 9396.txt
# -rwxr-xr-x 1 root root  2796 Feb  2 12:20 9402.txt
# -rwxr-xr-x 1 root root   128 Feb  2 12:19 940.txt
# -rwxr-xr-x 1 root root   264 Feb  2 12:20 9412.txt
# -rwxr-xr-x 1 root root   204 Feb  2 12:21 9424.txt
# -rwxr-xr-x 1 root root   101 Feb  2 12:21 9439.txt
# -rwxr-xr-x 1 root root   178 Feb  2 12:19 945.txt
# -rwxr-xr-x 1 root root   119 Feb  2 12:20 9464.txt
# -rwxr-xr-x 1 root root    11 Feb  2 12:20 9469.txt
# -rwxr-xr-x 1 root root   976 Feb  2 12:20 9473.txt
# -rwxr-xr-x 1 root root   154 Feb  2 12:20 9474.txt
# -rwxr-xr-x 1 root root   799 Feb  2 12:20 9490.txt
# -rwxr-xr-x 1 root root   235 Feb  2 12:20 9493.txt
# -rwxr-xr-x 1 root root   278 Feb  2 12:21 9497.txt
# -rwxr-xr-x 1 root root  2031 Feb  2 12:20 94.txt
# -rwxr-xr-x 1 root root   146 Feb  2 12:21 9514.txt
# -rwxr-xr-x 1 root root  1211 Feb  2 12:21 9526.txt
# -rwxr-xr-x 1 root root  3815 Feb  2 12:20 9531.txt
# -rwxr-xr-x 1 root root   226 Feb  2 12:21 9536.txt
# -rwxr-xr-x 1 root root   803 Feb  2 12:20 9545.txt
# -rwxr-xr-x 1 root root   480 Feb  2 12:20 9552.txt
# -rwxr-xr-x 1 root root   249 Feb  2 12:19 9554.txt
# -rwxr-xr-x 1 root root    60 Feb  2 12:20 9558.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:20 9563.txt
# -rwxr-xr-x 1 root root   242 Feb  2 12:20 9576.txt
# -rwxr-xr-x 1 root root   687 Feb  2 12:19 9580.txt
# -rwxr-xr-x 1 root root   107 Feb  2 12:20 9595.txt
# -rwxr-xr-x 1 root root   987 Feb  2 12:21 9598.txt
# -rwxr-xr-x 1 root root  2102 Feb  2 12:20 959.txt
# -rwxr-xr-x 1 root root    55 Feb  2 12:20 9608.txt
# -rwxr-xr-x 1 root root   123 Feb  2 12:20 9609.txt
# -rwxr-xr-x 1 root root   612 Feb  2 12:20 9611.txt
# -rwxr-xr-x 1 root root    66 Feb  2 12:20 9621.txt
# -rwxr-xr-x 1 root root    98 Feb  2 12:21 9633.txt
# -rwxr-xr-x 1 root root   164 Feb  2 12:21 9637.txt
# -rwxr-xr-x 1 root root    45 Feb  2 12:21 9638.txt
# -rwxr-xr-x 1 root root    18 Feb  2 12:20 9642.txt
# -rwxr-xr-x 1 root root     0 Feb  2 12:20 9643.txt
# -rwxr-xr-x 1 root root   139 Feb  2 12:20 9645.txt
# -rwxr-xr-x 1 root root   250 Feb  2 12:21 9646.txt
# -rwxr-xr-x 1 root root  3170 Feb  2 12:21 9648.txt
# -rwxr-xr-x 1 root root   111 Feb  2 12:20 9662.txt
# -rwxr-xr-x 1 root root  1634 Feb  2 12:19 9699.txt
# -rwxr-xr-x 1 root root    49 Feb  2 12:20 9700.txt
# -rwxr-xr-x 1 root root   695 Feb  2 12:21 9702.txt
# -rwxr-xr-x 1 root root   302 Feb  2 12:19 971.txt
# -rwxr-xr-x 1 root root   460 Feb  2 12:20 9722.txt
# -rwxr-xr-x 1 root root   382 Feb  2 12:21 9725.txt
# -rwxr-xr-x 1 root root   279 Feb  2 12:20 9726.txt
# -rwxr-xr-x 1 root root  1104 Feb  2 12:20 9732.txt
# -rwxr-xr-x 1 root root   464 Feb  2 12:21 9754.txt
# -rwxr-xr-x 1 root root  1682 Feb  2 12:21 9766.txt
# -rwxr-xr-x 1 root root  1413 Feb  2 12:19 9768.txt
# -rwxr-xr-x 1 root root  1239 Feb  2 12:19 9773.txt
# -rwxr-xr-x 1 root root   339 Feb  2 12:21 9776.txt
# -rwxr-xr-x 1 root root   352 Feb  2 12:20 977.txt
# -rwxr-xr-x 1 root root   837 Feb  2 12:21 9785.txt
# -rwxr-xr-x 1 root root    64 Feb  2 12:21 9789.txt
# -rwxr-xr-x 1 root root    44 Feb  2 12:20 9792.txt
# -rwxr-xr-x 1 root root   142 Feb  2 12:20 9797.txt
# -rwxr-xr-x 1 root root    62 Feb  2 12:21 979.txt
# -rwxr-xr-x 1 root root  1406 Feb  2 12:20 9800.txt
# -rwxr-xr-x 1 root root   668 Feb  2 12:19 9801.txt
# -rwxr-xr-x 1 root root   180 Feb  2 12:20 9804.txt
# -rwxr-xr-x 1 root root  1400 Feb  2 12:19 9816.txt
# -rwxr-xr-x 1 root root   436 Feb  2 12:21 9818.txt
# -rwxr-xr-x 1 root root   143 Feb  2 12:20 9823.txt
# -rwxr-xr-x 1 root root   935 Feb  2 12:19 9827.txt
# -rwxr-xr-x 1 root root    50 Feb  2 12:21 9830.txt
# -rwxr-xr-x 1 root root    59 Feb  2 12:20 983.txt
# -rwxr-xr-x 1 root root  1165 Feb  2 12:21 984.txt
# -rwxr-xr-x 1 root root   698 Feb  2 12:21 9855.txt
# -rwxr-xr-x 1 root root   284 Feb  2 12:20 985.txt
# -rwxr-xr-x 1 root root   347 Feb  2 12:21 9865.txt
# -rwxr-xr-x 1 root root   966 Feb  2 12:20 9869.txt
# -rwxr-xr-x 1 root root   537 Feb  2 12:19 9889.txt
# -rwxr-xr-x 1 root root   244 Feb  2 12:21 9897.txt
# -rwxr-xr-x 1 root root   356 Feb  2 12:21 9900.txt
# -rwxr-xr-x 1 root root   197 Feb  2 12:21 9901.txt
# -rwxr-xr-x 1 root root   125 Feb  2 12:19 9902.txt
# -rwxr-xr-x 1 root root   285 Feb  2 12:20 9919.txt
# -rwxr-xr-x 1 root root   865 Feb  2 12:20 9920.txt
# -rwxr-xr-x 1 root root   357 Feb  2 12:20 9924.txt
# -rwxr-xr-x 1 root root   362 Feb  2 12:21 992.txt
# -rwxr-xr-x 1 root root   226 Feb  2 12:21 9936.txt
# -rwxr-xr-x 1 root root   145 Feb  2 12:21 9945.txt
# -rwxr-xr-x 1 root root   718 Feb  2 12:20 994.txt
# -rwxr-xr-x 1 root root   128 Feb  2 12:20 9951.txt
# -rwxr-xr-x 1 root root   176 Feb  2 12:20 9969.txt
# -rwxr-xr-x 1 root root   637 Feb  2 12:20 9970.txt
# -rwxr-xr-x 1 root root   406 Feb  2 12:21 9977.txt
# -rwxr-xr-x 1 root root   882 Feb  2 12:21 9982.txt
# -rwxr-xr-x 1 root root   156 Feb  2 12:21 9988.txt
# -rwxr-xr-x 1 root root  1422 Feb  2 12:21 998.txt
# -rwxr-xr-x 1 root root   368 Feb  2 12:21 9998.txt
# -rwxr-xr-x 1 root root    83 Feb  2 12:21 9999.txt

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">University of Uah Data Science for Health</span> by <span xmlns:cc="http://creativecommons.org/ns#" property="cc:attributionName">Brian E. Chapman</span> is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.
